# %%
import sys
sys.path.append('../bggcomplex')

from bggcomplex import BGGComplex
from fast_module import FastLieAlgebraCompositeModule, FastModuleFactory, BGGCohomology
from tqdm.auto import tqdm
from compute_maps import BGGMapSolver
import numpy as np

# %% [markdown]
# Let's first fix the problem with compute maps. This should make it a bit easier to diagnose the problems with the diff computation.

# %%
%%prun
d='F4'
BGG = BGGComplex(d)
factory = FastModuleFactory(BGG.LA)
component_dic = {'u':factory.build_component('u','coad',subset=[1,2,4])}
u_dim = len(component_dic['u'].basis)
print('dim of u is %d for root system %s' % (u_dim, d))

pbar1 = tqdm(range(u_dim+1))
pbar2 = tqdm()
pbar3 = tqdm()
for k in pbar1:
    components = [[('u',k,'wedge')]]
    module = FastLieAlgebraCompositeModule(factory,components,component_dic)

    cohom = BGGCohomology(BGG, module,pbars=[pbar2,pbar3])

    cohom.cohomology_LaTeX(complex_string=r'X_{'+d+r'},\wedge^{'+str(k)+'}T_X')#,i=1)
# Out:
# dim of u is 20 for root system F4
# HBox(children=(IntProgress(value=0, max=21), HTML(value=u'')))
# HBox(children=(IntProgress(value=1, bar_style=u'info', max=1), HTML(value=u'')))
# HBox(children=(IntProgress(value=1, bar_style=u'info', max=1), HTML(value=u'')))
# $$\mathrm H^{0}(X_{F4},\wedge^{0}T_X)=\mathbb{C}$$
# $$\mathrm H^{0}(X_{F4},\wedge^{1}T_X)=L\left( 2\alpha_{1}+ 3\alpha_{2}+ 4\alpha_{3}+ 2\alpha_{4}\right)$$
# $$\mathrm H^{0}(X_{F4},\wedge^{2}T_X)=L\left( 2\alpha_{1}+ 3\alpha_{2}+ 4\alpha_{3}+ 2\alpha_{4}\right)\oplus L\left( 3\alpha_{1}+ 6\alpha_{2}+ 8\alpha_{3}+ 4\alpha_{4}\right)$$
# $$\mathrm H^{0}(X_{F4},\wedge^{3}T_X)=L\left( 2\alpha_{1}+ 4\alpha_{2}+ 6\alpha_{3}+ 4\alpha_{4}\right)\oplus L\left( 3\alpha_{1}+ 6\alpha_{2}+ 8\alpha_{3}+ 4\alpha_{4}\right)\oplus L\left( 4\alpha_{1}+ 6\alpha_{2}+ 8\alpha_{3}+ 4\alpha_{4}\right)\oplus L\left( 4\alpha_{1}+ 8\alpha_{2}+ 12\alpha_{3}+ 6\alpha_{4}\right)$$
# $$\mathrm H^{0}(X_{F4},\wedge^{4}T_X)=L\left( 2\alpha_{1}+ 4\alpha_{2}+ 6\alpha_{3}+ 4\alpha_{4}\right)^{2}\oplus L\left( 3\alpha_{1}+ 5\alpha_{2}+ 7\alpha_{3}+ 4\alpha_{4}\right)\oplus L\left( 4\alpha_{1}+ 6\alpha_{2}+ 8\alpha_{3}+ 4\alpha_{4}\right)\oplus L\left( 3\alpha_{1}+ 6\alpha_{2}+ 9\alpha_{3}+ 5\alpha_{4}\right)\oplus L\left( 4\alpha_{1}+ 7\alpha_{2}+ 10\alpha_{3}+ 6\alpha_{4}\right)\oplus L\left( 4\alpha_{1}+ 8\alpha_{2}+ 12\alpha_{3}+ 6\alpha_{4}\right)\oplus L\left( 5\alpha_{1}+ 9\alpha_{2}+ 12\alpha_{3}+ 6\alpha_{4}\right)\oplus L\left( 5\alpha_{1}+ 10\alpha_{2}+ 15\alpha_{3}+ 8\alpha_{4}\right)$$
# $$\mathrm H^{1}(X_{F4},\wedge^{4}T_X)=L\left( 4\alpha_{1}+ 7\alpha_{2}+ 10\alpha_{3}+ 6\alpha_{4}\right)$$
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7c71c43b4ff4> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'prun', u'', u"d='F4'\nBGG = BGGComplex(d)\nfactory = FastModuleFactory(BGG.LA)\ncomponent_dic = {'u':factory.build_component('u','coad',subset=[1,2,4])}\nu_dim = len(component_dic['u'].basis)\nprint('dim of u is %d for root system %s' % (u_dim, d))\n\npbar1 = tqdm(range(u_dim+1))\npbar2 = tqdm()\npbar3 = tqdm()\nfor k in pbar1:\n    components = [[('u',k,'wedge')]]\n    module = FastLieAlgebraCompositeModule(factory,components,component_dic)\n\n    cohom = BGGCohomology(BGG, module,pbars=[pbar2,pbar3])\n\n    cohom.cohomology_LaTeX(complex_string=r'X_{'+d+r'},\\wedge^{'+str(k)+'}T_X')#,i=1)")
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-54> in prun(self, parameter_s, cell)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in prun(self, parameter_s, cell)
#     279             arg_str += '\n' + cell
#     280         arg_str = self.shell.input_splitter.transform_cell(arg_str)
# --> 281         return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#     282
#     283     def _run_with_profiler(self, code, opts, namespace):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in _run_with_profiler(self, code, opts, namespace)
#     301         prof = profile.Profile()
#     302         try:
# --> 303             prof = prof.runctx(code, namespace, namespace)
#     304             sys_exit = ''
#     305         except SystemExit:
#
# /opt/sagemath-8.6/local/lib/python2.7/cProfile.pyc in runctx(self, cmd, globals, locals)
#     138         self.enable()
#     139         try:
# --> 140             exec cmd in globals, locals
#     141         finally:
#     142             self.disable()
#
# <string> in <module>()
#
# /cygdrive/c/Git/BGG/bggcomplex/fast_module.pyc in cohomology_LaTeX(self, i, complex_string, only_non_zero, print_betti, print_modules, only_strings, compact)
#     801         # compute cohomology. If cohomology is trivial and only_non_zero is true, return nothing.
#     802         if i is None:
# --> 803             cohoms = [(j, self.cohomology(j)) for j in range(self.BGG.max_word_length+1)]
#     804             max_len = max([len(cohom) for _, cohom in cohoms])
#     805             if max_len==0:
#
# /cygdrive/c/Git/BGG/bggcomplex/fast_module.pyc in cohomology(self, i)
#     760         # For non-isolated weights, multiplicity is computed through the BGG differential
#     761         for w in dominant_non_trivial:
# --> 762             cohom_dim = self.cohomology_component(w, i)
#     763             if self.pbar1 is not None:
#     764                 self.pbar1.update()
#
# /cygdrive/c/Git/BGG/bggcomplex/fast_module.pyc in cohomology_component(self, mu, i)
#     703             self.pbar1.set_description(str(mu)+', maps')
#     704         mu_converted = self.BGG.weight_to_alpha_sum(self.BGG._tuple_to_weight(mu))
# --> 705         self.BGG.compute_maps(mu_converted, pbar=self.pbar2, column=i)
#     706
#     707         if self.pbar1 is not None:
#
# /cygdrive/c/Git/BGG/bggcomplex/bggcomplex.py in compute_maps(self, root, column, check, pbar)
#     185             cached_result = None
#     186         MapSolver = BGGMapSolver(self,  root, pbar=pbar, cached_results=cached_result)
# --> 187         self._maps[root] = MapSolver.solve(column=column)
#     188         if check:
#     189             maps_OK = MapSolver.check_maps()
#
# /cygdrive/c/Git/BGG/bggcomplex/compute_maps.pyc in solve(self, column)
#     134             self._get_available_problems(final_column=c)
#     135             for problem in self.problem_dic.values():
# --> 136                 self.solve_problem(problem)
#     137                 if self.pbar is not None:
#     138                     self.pbar.update()
#
# /cygdrive/c/Git/BGG/bggcomplex/compute_maps.pyc in solve_problem(self, problem)
#     189
#     190         if problem['side'] == 'right':
# --> 191             LHS = [p* problem['known_LHS'] for p in basis]
#     192         if problem['side'] == 'left':
#     193             LHS = [problem['known_LHS'] * p for p in basis]
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>(***failed resolving arguments***)
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>((element, coeff))
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>((element, coeff))
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>((element, coeff))
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>((element, coeff))
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>(***failed resolving arguments***)
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>(***failed resolving arguments***)
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>(***failed resolving arguments***)
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>(***failed resolving arguments***)
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     437         terms += self.monomial(lead * trail)
#     438
# --> 439         product = self.monomial(lhs // trail) * terms * self.monomial(rhs // lead)
#     440
#     441         # add to cache if degree is low enough
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12023)()
#    1515         cdef int cl = classify_elements(left, right)
#    1516         if HAVE_SAME_PARENT(cl):
# -> 1517             return (<Element>left)._mul_(right)
#    1518         if BOTH_ARE_ELEMENT(cl):
#    1519             return coercion_model.bin_op(left, right, mul)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:12373)()
#    1561             raise bin_op_exception('*', self, other)
#    1562         else:
# -> 1563             return python_op(other)
#    1564
#    1565     cdef _mul_long(self, long n):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/coercion_methods.pyx in sage.categories.coercion_methods._mul_parent (build/cythonized/sage/categories/coercion_methods.c:2330)()
#      53         True
#      54     """
# ---> 55     return (<Element>self)._parent.product(self, other)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in _product_from_product_on_basis_multiply(self, left, right)
#     219                 """
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
# --> 221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
#     222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in linear_combination(self, iter_of_elements_coeff, factor_on_left)
#    1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
# -> 1023                                                         factor_on_left=factor_on_left ),
#    1024                                remove_zeros=False)
#    1025
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3480)()
#     315     return result
#     316
# --> 317 cpdef dict linear_combination(dict_factor_iter, bint factor_on_left=True):
#     318     r"""
#     319     Return the pointwise addition of dictionaries with coefficients.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/data_structures/blas_dict.pyx in sage.data_structures.blas_dict.linear_combination (build/cythonized/sage/data_structures/blas_dict.c:3118)()
#     351     cdef list for_removal
#     352
# --> 353     for D, a in dict_factor_iter:
#     354         if not a: # We multiply by 0, so nothing to do
#     355             continue
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/combinat/free_module.pyc in <genexpr>((element, coeff))
#    1019             20*B[1] + 20*B[2]
#    1020         """
# -> 1021         return self._from_dict(blas.linear_combination( ((element._monomial_coefficients, coeff)
#    1022                                                         for element, coeff in iter_of_elements_coeff),
#    1023                                                         factor_on_left=factor_on_left ),
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/magmatic_algebras.pyc in <genexpr>((mon_left, coeff_left))
#     220                 return self.linear_combination( ( self.product_on_basis( mon_left, mon_right ), coeff_left * coeff_right )
#     221                                                   for ( mon_left, coeff_left ) in six.iteritems(left.monomial_coefficients())
# --> 222                                                   for ( mon_right, coeff_right ) in six.iteritems(right.monomial_coefficients()) )
#     223
#     224         class FiniteDimensional(CategoryWithAxiom_over_base_ring):
#
# /cygdrive/c/Git/BGG/bggcomplex/pbw.pyc in product_on_basis(self, lhs, rhs)
#     430         # Create the commutator
#     431         # We have xy - yx = [x, y] -> xy = yx + [x, y] and we have x > y
# --> 432         terms = self._g.monomial(trail).bracket(self._g.monomial(lead))
#     433         lead = I.gen(lead)
#     434         trail = I.gen(trail)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/algebras/lie_algebras/lie_algebra_element.pyx in sage.algebras.lie_algebras.lie_algebra_element.StructureCoefficientsElement.bracket (build/cythonized/sage/algebras/lie_algebras/lie_algebra_element.c:10162)()
#     764                             is_latex=True, strip_one=True)
#     765
# --> 766     cpdef bracket(self, right):
#     767         """
#     768         Return the Lie bracket ``[self, right]``.
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/algebras/lie_algebras/lie_algebra_element.pyx in sage.algebras.lie_algebras.lie_algebra_element.StructureCoefficientsElement.bracket (build/cythonized/sage/algebras/lie_algebras/lie_algebra_element.c:10112)()
#     780         if not have_same_parent(self, right):
#     781             self, right = coercion_model.canonical_coercion(self, right)
# --> 782         return self._bracket_(right)
#     783
#     784     # We need this method because the LieAlgebra.bracket method (from the
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/algebras/lie_algebras/lie_algebra_element.pyx in sage.algebras.lie_algebras.lie_algebra_element.StructureCoefficientsElement._bracket_ (build/cythonized/sage/algebras/lie_algebras/lie_algebra_element.c:10736)()
#     819                     for i3 in range(d):
#     820                         ret[i3] -= prod_c1_c2 * v[i3]
# --> 821         return type(self)(P, P._M(ret))
#     822
#     823     def __iter__(self):
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9237)()
#     887         if mor is not None:
#     888             if no_extra_args:
# --> 889                 return mor._call_(x)
#     890             else:
#     891                 return mor._call_with_args(x, args, kwds)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4550)()
#     155         cdef Parent C = self._codomain
#     156         try:
# --> 157             return C._element_constructor(x)
#     158         except Exception:
#     159             if print_warnings:
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/modules/free_module.pyc in _element_constructor_(self, e, *args, **kwds)
#    5567         return self.base_ring()
#    5568
# -> 5569     def _element_constructor_(self, e, *args, **kwds):
#    5570         """
#    5571         Create an element of this vector space.
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
d='F4'
BGG = BGGComplex(d)

# %%
mu = (3,6,9,6)
mu_alpha = BGG.weight_to_alpha_sum(BGG._tuple_to_weight(mu))
solver = BGGMapSolver(BGG, mu_alpha)

# %%
pbw = solver.partition_to_PBW((17, 16))
pbw
# Out:
# PBW[-alpha[1] - 2*alpha[2] - 2*alpha[3] - alpha[4]]*PBW[-alpha[1] - alpha[2] - 2*alpha[3] - 2*alpha[4]]

# %%
a1 = list(pbw)[0][0].leading_support()
display(a1)
a2 = list(pbw)[0][0].trailing_support()
a2
# Out:
# -alpha[1] - 2*alpha[2] - 2*alpha[3] - alpha[4]
# -alpha[1] - alpha[2] - 2*alpha[3] - 2*alpha[4]

# %%
BGG.PBW._basis_key(a1)
# Out:
# 44

# %%
BGG.PBW._basis_key(a2)
# Out:
# 45

# %%
lie_alg_order = {k:i for i,k in enumerate(BGG.LA.basis().keys())}
ordered_roots = sorted([BGG.weight_to_alpha_sum(r) for r in BGG.domain.negative_roots()],key=lambda r: lie_alg_order[r])
[-BGG.alpha_sum_to_array(r) for r in ordered_roots]
# Out:
# [array([0, 0, 0, 1]),
#  array([0, 0, 1, 0]),
#  array([0, 1, 0, 0]),
#  array([1, 0, 0, 0]),
#  array([0, 0, 1, 1]),
#  array([0, 1, 1, 0]),
#  array([1, 1, 0, 0]),
#  array([0, 1, 1, 1]),
#  array([0, 1, 2, 0]),
#  array([1, 1, 1, 0]),
#  array([0, 1, 2, 1]),
#  array([1, 1, 1, 1]),
#  array([1, 1, 2, 0]),
#  array([0, 1, 2, 2]),
#  array([1, 2, 2, 0]),
#  array([1, 1, 2, 1]),
#  array([1, 2, 2, 1]),
#  array([1, 1, 2, 2]),
#  array([1, 2, 3, 1]),
#  array([1, 2, 2, 2]),
#  array([1, 2, 3, 2]),
#  array([1, 2, 4, 2]),
#  array([1, 3, 4, 2]),
#  array([2, 3, 4, 2])]

# %%
BGG.neg_roots
# Out:
# [array([0, 0, 0, 1]),
#  array([0, 0, 1, 0]),
#  array([0, 1, 0, 0]),
#  array([1, 0, 0, 0]),
#  array([0, 0, 1, 1]),
#  array([0, 1, 1, 0]),
#  array([1, 1, 0, 0]),
#  array([0, 1, 1, 1]),
#  array([0, 1, 2, 0]),
#  array([1, 1, 1, 0]),
#  array([0, 1, 2, 1]),
#  array([1, 1, 1, 1]),
#  array([1, 1, 2, 0]),
#  array([0, 1, 2, 2]),
#  array([1, 1, 2, 1]),
#  array([1, 2, 2, 0]),
#  array([1, 1, 2, 2]),
#  array([1, 2, 2, 1]),
#  array([1, 2, 2, 2]),
#  array([1, 2, 3, 1]),
#  array([1, 2, 3, 2]),
#  array([1, 2, 4, 2]),
#  array([1, 3, 4, 2]),
#  array([2, 3, 4, 2])]

# %%
list(enumerate(BGG.neg_roots))
# Out:
# [(0, array([0, 0, 0, 1])),
#  (1, array([0, 0, 1, 0])),
#  (2, array([0, 1, 0, 0])),
#  (3, array([1, 0, 0, 0])),
#  (4, array([0, 0, 1, 1])),
#  (5, array([0, 1, 1, 0])),
#  (6, array([1, 1, 0, 0])),
#  (7, array([0, 1, 1, 1])),
#  (8, array([0, 1, 2, 0])),
#  (9, array([1, 1, 1, 0])),
#  (10, array([0, 1, 2, 1])),
#  (11, array([1, 1, 1, 1])),
#  (12, array([1, 1, 2, 0])),
#  (13, array([0, 1, 2, 2])),
#  (14, array([1, 1, 2, 1])),
#  (15, array([1, 2, 2, 0])),
#  (16, array([1, 1, 2, 2])),
#  (17, array([1, 2, 2, 1])),
#  (18, array([1, 2, 2, 2])),
#  (19, array([1, 2, 3, 1])),
#  (20, array([1, 2, 3, 2])),
#  (21, array([1, 2, 4, 2])),
#  (22, array([1, 3, 4, 2])),
#  (23, array([2, 3, 4, 2]))]

# %%
BGG = BGGComplex('F4')
sorted_alphas = sorted([BGG.weight_to_alpha_sum(r) for r in BGG.domain.negative_roots()])
list(enumerate(sorted_alphas))
# Out:
# [(0, -2*alpha[1] - 3*alpha[2] - 4*alpha[3] - 2*alpha[4]),
#  (1, -alpha[1]),
#  (2, -alpha[1] - 3*alpha[2] - 4*alpha[3] - 2*alpha[4]),
#  (3, -alpha[1] - 2*alpha[2] - 4*alpha[3] - 2*alpha[4]),
#  (4, -alpha[1] - 2*alpha[2] - 3*alpha[3] - 2*alpha[4]),
#  (5, -alpha[1] - 2*alpha[2] - 3*alpha[3] - alpha[4]),
#  (6, -alpha[1] - 2*alpha[2] - 2*alpha[3]),
#  (7, -alpha[1] - 2*alpha[2] - 2*alpha[3] - 2*alpha[4]),
#  (8, -alpha[1] - 2*alpha[2] - 2*alpha[3] - alpha[4]),
#  (9, -alpha[1] - alpha[2]),
#  (10, -alpha[1] - alpha[2] - 2*alpha[3]),
#  (11, -alpha[1] - alpha[2] - 2*alpha[3] - 2*alpha[4]),
#  (12, -alpha[1] - alpha[2] - 2*alpha[3] - alpha[4]),
#  (13, -alpha[1] - alpha[2] - alpha[3]),
#  (14, -alpha[1] - alpha[2] - alpha[3] - alpha[4]),
#  (15, -alpha[2]),
#  (16, -alpha[2] - 2*alpha[3]),
#  (17, -alpha[2] - 2*alpha[3] - 2*alpha[4]),
#  (18, -alpha[2] - 2*alpha[3] - alpha[4]),
#  (19, -alpha[2] - alpha[3]),
#  (20, -alpha[2] - alpha[3] - alpha[4]),
#  (21, -alpha[3]),
#  (22, -alpha[3] - alpha[4]),
#  (23, -alpha[4])]

# %%
sorted_alphas[15]<sorted_alphas[9]
# Out:
# False
