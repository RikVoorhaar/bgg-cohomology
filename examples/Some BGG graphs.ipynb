# %%
from bggcohomology.bggcomplex import BGGComplex
from bggcohomology.fast_module import LieAlgebraCompositeModule, ModuleFactory, BGGCohomology, WeightSet
import numpy as np

# %% [markdown]
# Using this code we can display the BGG complex as a graph, and describe all the maps in the complex. Shown here is the complex for $B3$, together with the maps for the zero weight.

# %%
d = 'A3'
BGG = BGGComplex(d)
BGG.plot_graph()
BGG.display_maps([0,0,0])
# Out:
# Graphics object consisting of 59 graphics primitives
# $$\to1,\,\,\,f_{1}$$
# $$\to2,\,\,\,f_{2}$$
# $$\to3,\,\,\,f_{3}$$
# $$1\to12,\,\,2\,f_{12} +\,f_{2}\,f_{1}$$
# $$1\to21,\,\,\,f_{2}^{2}$$
# $$1\to31,\,\,\,f_{3}$$
# $$2\to12,\,\,\,f_{1}^{2}$$
# $$2\to21,\,\,-\,f_{12} +\,f_{2}\,f_{1}$$
# $$2\to23,\,\,2\,f_{23} +\,f_{3}\,f_{2}$$
# $$2\to32,\,\,\,f_{3}^{2}$$
# $$3\to23,\,\,\,f_{2}^{2}$$
# $$3\to31,\,\,\,f_{1}$$
# $$3\to32,\,\,-\,f_{23} +\,f_{3}\,f_{2}$$
# $$12\to121,\,\,\,f_{2}$$
# $$12\to123,\,\,-4\,f_{123} +2\,f_{1}\,f_{23} +3\,f_{3}\,f_{12} +\,f_{3}\,f_{2}\,f_{1}$$
# $$12\to312,\,\,\,f_{3}^{2}$$
# $$21\to121,\,\,\,f_{1}$$
# $$21\to231,\,\,3\,f_{23} +\,f_{3}\,f_{2}$$
# $$21\to321,\,\,\,f_{3}^{3}$$
# $$23\to123,\,\,\,f_{1}^{3}$$
# $$23\to231,\,\,-2\,f_{12} +\,f_{2}\,f_{1}$$
# $$23\to232,\,\,\,f_{3}$$
# $$31\to123,\,\,6\,f_{12}^{2} +6\,f_{2}\,f_{1}\,f_{12} +\,f_{2}^{2}\,f_{1}^{2}$$
# $$31\to231,\,\,\,f_{2}^{3}$$
# ...

# %%
BGG.weight_to_alpha_sum(tuple([0,0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-fbf4d53d02d8> in <module>()
#       1
# ----> 2 BGG.weight_to_alpha_sum(tuple([Integer(0),Integer(0)]))
#
# /cygdrive/c/git/GitHub/BGG/bggcohomology/bggcomplex.py in weight_to_alpha_sum(self, weight)
#     274         if check:
#     275             maps_OK = MapSolver.check_maps()
# --> 276             if not maps_OK:
#     277                 raise ValueError(
#     278                     "For root %s the map solver produced something wrong" % root
#
# /cygdrive/c/git/GitHub/BGG/bggcohomology/bggcomplex.py in _weight_to_tuple(self, weight)
#     264
#     265         """
# --> 266
#     267         # If the maps are not in the cache, compute them and cache the result
#     268         if root in self._maps:
#
# AttributeError: 'tuple' object has no attribute 'to_vector'

# %%
type(list(BGG.alpha_to_index.keys())[0])
# Out:
# <class 'sage.combinat.root_system.root_space.RootSpace_with_category.element_class'>

# %%
BGG.weight_to_alpha_sum(BGG._tuple_to_weight([2,1]))
# Out:
# 2*alpha[1] + alpha[2]

# %%
w=BGG.W.an_element()
BGG.fast_dot_action('12',BGG.weight_to_alpha_sum(BGG._tuple_to_weight([2,1])))
# Out:
# -3*alpha[1]

# %%
BGG.compute_maps(BGG._tuple_to_weight([0,0]))
# Out:
# {('', '1'): PBW[-alpha[1]],
#  ('', '2'): PBW[-alpha[2]],
#  ('', '3'): PBW[-alpha[3]],
#  ('3', '31'): PBW[-alpha[1]],
#  ('3', '23'): PBW[-alpha[2]]^2,
#  ('2', '12'): PBW[-alpha[1]]^2,
#  ('2', '32'): PBW[-alpha[3]]^2,
#  ('1', '21'): PBW[-alpha[2]]^2,
#  ('1', '31'): PBW[-alpha[3]],
#  ('32', '312'): PBW[-alpha[1]]^2,
#  ('32', '232'): PBW[-alpha[2]],
#  ('23', '123'): PBW[-alpha[1]]^3,
#  ('23', '232'): PBW[-alpha[3]],
#  ('21', '121'): PBW[-alpha[1]],
#  ('21', '321'): PBW[-alpha[3]]^3,
#  ('31', '231'): PBW[-alpha[2]]^3,
#  ('12', '121'): PBW[-alpha[2]],
#  ('12', '312'): PBW[-alpha[3]]^2,
#  ('321', '3121'): PBW[-alpha[1]],
#  ('321', '2321'): PBW[-alpha[2]],
#  ('232', '1232'): PBW[-alpha[1]]^3,
#  ('231', '1231'): PBW[-alpha[1]]^2,
#  ('231', '2321'): PBW[-alpha[3]]^2,
#  ('312', '2312'): PBW[-alpha[2]]^3,
#  ('123', '1231'): PBW[-alpha[2]],
#  ('123', '1232'): PBW[-alpha[3]],
#  ('121', '3121'): PBW[-alpha[3]]^3,
#  ('2321', '12321'): PBW[-alpha[1]]^2,
# ...
