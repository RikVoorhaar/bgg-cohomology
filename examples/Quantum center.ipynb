# %% [markdown]
# # Tutorial: center of the small Quantum group
#
# This page appears both rendered to HTML in the docs, and as an interactive notebook in the `/examples` folder in the repository.
#
# ## Introduction
#
# This tutorial will show how to compute the center of the small quantum group, as described in the two papers by Annach Lachowska and You Qi:
#
# https://arxiv.org/abs/1604.07380v3
#
# https://arxiv.org/abs/1703.02457v3
#
# Let $G$ be a complex simple Lie group, and let $P$ be a parabolic subgroup. Then we consider the cotangent bundle of the associated partial flag variety:
# $$
#     \tilde{\mathcal N}_P :=T^*(G/P)
# $$
#
# We are then interested in computing
# $$HH^s(\tilde{\mathcal N}_P)\cong \bigoplus_{i+j+k=s}H^i(\tilde{\mathcal N}_P,\wedge^jT\tilde{\mathcal N}_P)^k$$
#
# This can be computed by using the BGG resolution. We define the following module:
# $$M_j^k = \bigoplus_r \operatorname{Sym}^{j-r+k/2}\mathfrak u_P\otimes \wedge^r\mathfrak g\otimes \wedge^{j-r}\mathfrak n_P$$
#
# Let $\Delta\colon\mathfrak p\to \mathfrak g\oplus \mathfrak u_P\otimes\mathfrak n_P$ be given by the inclusion in the first component and in the second component by the adjoint action (after identifying $\operatorname{End}(\mathfrak n_P)$ with $\mathfrak u_P\otimes \mathfrak n_P$). Then $\Delta$ induces a map $M_{j-1}^k\to M_j^k$. We define the module
#
# $$E_j^k = M_j^k\big/\Delta(M_{j-1}^k)$$
#
# Then the cohomology of the BGG resolution of $E_j^k$ in degree $i$ with respect to a dominant weight $\mu$ computes the multiplicity of $\mu$ of $H^i(\tilde{\mathcal N}_P,\wedge^jT\tilde{\mathcal N}_P)^k$.

# %% [markdown]
# ## Example

# %% [markdown]
# We begin by loading the required packages.

# %%
from bggcohomology.la_modules import BGGCohomology
from bggcohomology.bggcomplex import BGGComplex
from bggcohomology.quantum_center import *
from bggcohomology.weight_set import WeightSet
from bggcohomology.cohomology import compute_diff

# %% [markdown]
# Now let us compute a simple example and set $G=A_2$. We will compute $H^0(\tilde{\mathcal N}_0,\wedge^2T\tilde{\mathcal N}_0)^{-2}$. Here the subscript $0$ indicates the principal block. The principal block corresponds to the parameter `subset=[]`. The other parameters are `s,i,j,k`, and they satisfy `i+j+k=s` and `j>=i`.
#
# If we want to change the parabolic subalgebra $P$ then we can change `subset` to e.g. `subset=[1]` for
# $$\mathfrak p = \mathfrak b\oplus\mathbb C\langle e_1\rangle=\mathbb C\langle e_1,f_1,f_2,f_{12} \rangle,\qquad \mathfrak u_P = \mathbb C\langle e_{12},e_2\rangle,\qquad \mathfrak n_P = \mathbb C\langle f_{12},f_2\rangle$$

# %%
import datetime
td = datetime.timedelta(seconds=float(1000.123))
str(td)
# Out:
# '0:16:40.123000'

# %%
BGG = BGGComplex('A2')
s = 1
i = 1
j = 2
k = s-i-j
print('i+j=%d, j-i=%d, k=%d\n'%(i+j,j-i,k))

subset = [1]
mjk = Mjk(BGG,j,k,subset=subset)
cohom = BGGCohomology(BGG, mjk, coker=Eijk_basis(BGG,j,k,subset=subset, sparse=True))
cohom.cohomology_LaTeX(i=i,only_non_zero=False,print_modules=True,print_betti=True,complex_string=r'\tilde{\mathcal N}_0,\wedge^2T\tilde{\mathcal N}_0)^{-2}')
# Out:
# i+j=3, j-i=1, k=-2
# $\displaystyle \mathrm H^{1}(\tilde{\mathcal N}_0,\wedge^2T\tilde{\mathcal N}_0)^{-2})=\mathbb{C}$
# $\displaystyle \mathrm b^{1}(\tilde{\mathcal N}_0,\wedge^2T\tilde{\mathcal N}_0)^{-2})=1$

# %% [markdown]
# ## Bigraded tables
# The program can also produce bigraded tables. We decompose impose a bigrading on the total cohomology $HH^s(\tilde{\mathcal N}_P)$ by $a=i+j$ and $b = j-i$. Since the computation can take a while a progress bar is provided.
#
# Due to the $\mathfrak{sl}_2$ symmetry in the bigraded table, we only actually need to compute half of it. We can choose to either compute the whole table, or only half if it through the `half_only` parameter, and extend by symmetry. It's default value is `False`.
#
# The bigraded table can be rendered in LaTeX through the `display_ab_dic` function, which takes an additional parameter `extend_half` which computes the second half of the table from the first half through symmetry considerations. The produced LaTeX code can easily be copied. The code below also saves the tables to a LaTeX document.
#
# The parameter `compact` determines how the weight decomposition of the cohomology is displayed. E.g. with `compact=False` it would display $\mathbb C\oplus L(\alpha_1+\alpha_2)^2$ and with `compact=True` it gives $\mathbb C L_{1,1}^2$.

# %%
# %%prun -D prun.log
import pickle
import os
import itertools
from tqdm.auto import tqdm
os.makedirs('pickles', exist_ok=True)
os.makedirs('tables', exist_ok=True)

# Only compute cohomology for particular highest weight module
mu = (0,0,0,0)
#mu=(0,0)

# the parameters we actually want to change
diagram = 'A4'
BGG = BGGComplex(diagram)
subset=[]

# compute only half of the table, extend by symmetry
half_only = True
extend_half = half_only

# Exclude the top-left to bottom-right diagonal. If s=0, these should all be the trivial rep.
exclude_diagonal = True

# Display in full form
compact = True

# Load results if already computed
load_pickle = False

s=0
#for method in [0,1]:
#for s in itertools.count():
method = 0
for s in [0]:
    picklefile = os.path.join('pickles',f'{diagram}-s{s}-{subset}.pkl')
    if load_pickle and os.path.isfile(picklefile):
        previous_cohom = pickle.load(open(picklefile, 'rb'))
    else:
        previous_cohom = None
    texfile = os.path.join('tables',f'{diagram}-s{s}-{subset}.tex')
    cohom_dic = dict()
    with tqdm(all_abijk(BGG,s=s,subset=subset,half_only=half_only)) as inner_pbar:
        with tqdm(leave=None) as outer_pbar:
            map_pbar = tqdm()
            for a,b,i,j,k in inner_pbar:
                if previous_cohom is not None and (a,b) in previous_cohom:
                    cohom_dic[(a,b)]=previous_cohom[(a,b)]
                    inner_pbar.update()
                    continue
                if exclude_diagonal and s==0 and (a==b):
                    cohom_dic[(a,b)]=[((0,)*BGG.rank,1)]
                    inner_pbar.update()
                    continue
                inner_pbar.set_description('i+j= %d, j-i = %d'%(a,b))
                #coker = Eijk_basis(BGG,j,k,subset=subset,pbar=outer_pbar)
                mjk = Mjk(BGG,j,k,subset=subset)
                outer_pbar.set_description('Initializing cohomology')
                coker=Eijk_basis(BGG,j,k,subset=subset,sparse=True)
                cohom = BGGCohomology(BGG, mjk, 
                                      coker=coker,pbars = [outer_pbar,map_pbar])
                outer_pbar.set_description('Computing cohomology')
                cohom_list = cohom.cohomology(i, mu=mu)
                cohom_dic[(a,b)] = cohom_list
                with open(picklefile, 'wb') as f:
                    pickle.dump(cohom_dic,f)   
    print('-'*50)
    print(f'type {diagram}, table for s={s}:')
    cohom = BGGCohomology(BGG)
    cohom_dic = extend_from_symmetry(cohom_dic)
    latex_dic = {k:cohom.cohom_to_latex(c, compact=compact) for k,c in cohom_dic.items()}
    betti_dic = {k:cohom.betti_number(c) for k,c in cohom_dic.items()}
    tab1 = display_bigraded_table(latex_dic)
    tab2 = display_bigraded_table(betti_dic)
    tab3 = display_cohomology_stats(cohom_dic, BGG)
    with open(texfile, 'w') as f:
        f.write(prepare_texfile([tab1,tab2,tab3],title=f'type {diagram}, s={s}, subset={subset}'))
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# --------------------------------------------------
# type A4, table for s=0:
# $\displaystyle \begin{array}{r|l l l l l l l l l l l}
# 	{\scriptstyle i+j=0}&\mathbb{C}&&&&&&&&&&\\
# 	{\scriptstyle i+j=2}&\mathbb{C}^{4}&\mathbb{C}&&&&&&&&&\\
# 	{\scriptstyle i+j=4}&\mathbb{C}^{9}&\mathbb{C}^{5}&\mathbb{C}&&&&&&&&\\
# 	{\scriptstyle i+j=6}&\mathbb{C}^{15}&\mathbb{C}^{14}&\mathbb{C}^{5}&\mathbb{C}&&&&&&&\\
# 	{\scriptstyle i+j=8}&\mathbb{C}^{20}&\mathbb{C}^{29}&\mathbb{C}^{15}&\mathbb{C}^{5}&\mathbb{C}&&&&&&\\
# 	{\scriptstyle i+j=10}&\mathbb{C}^{22}&\mathbb{C}^{44}&\mathbb{C}^{33}&\mathbb{C}^{15}&\mathbb{C}^{5}&\mathbb{C}&&&&&\\
# 	{\scriptstyle i+j=12}&\mathbb{C}^{20}&\mathbb{C}^{51}&\mathbb{C}^{54}&\mathbb{C}^{34}&\mathbb{C}^{15}&\mathbb{C}^{5}&\mathbb{C}&&&&\\
# 	{\scriptstyle i+j=14}&\mathbb{C}^{15}&\mathbb{C}^{46}&\mathbb{C}^{66}&\mathbb{C}^{58}&\mathbb{C}^{34}&\mathbb{C}^{15}&\mathbb{C}^{5}&\mathbb{C}&&&\\
# 	{\scriptstyle i+j=16}&\mathbb{C}^{9}&\mathbb{C}^{31}&\mathbb{C}^{56}&\mathbb{C}^{66}&\mathbb{C}^{54}&\mathbb{C}^{33}&\mathbb{C}^{15}&\mathbb{C}^{5}&\mathbb{C}&&\\
# 	{\scriptstyle i+j=18}&\mathbb{C}^{4}&\mathbb{C}^{15}&\mathbb{C}^{31}&\mathbb{C}^{46}&\mathbb{C}^{51}&\mathbb{C}^{44}&\mathbb{C}^{29}&\mathbb{C}^{14}&\mathbb{C}^{5}&\mathbb{C}&\\
# 	{\scriptstyle i+j=20}&\mathbb{C}&\mathbb{C}^{4}&\mathbb{C}^{9}&\mathbb{C}^{15}&\mathbb{C}^{20}&\mathbb{C}^{22}&\mathbb{C}^{20}&\mathbb{C}^{15}&\mathbb{C}^{9}&\mathbb{C}^{4}&\mathbb{C}\\
# 	\hline h^{i,j}&{\scriptstyle j-i=0}&{\scriptstyle j-i=2}&{\scriptstyle j-i=4}&{\scriptstyle j-i=6}&{\scriptstyle j-i=8}&{\scriptstyle j-i=10}&{\scriptstyle j-i=12}&{\scriptstyle j-i=14}&{\scriptstyle j-i=16}&{\scriptstyle j-i=18}&{\scriptstyle j-i=20}
# \end{array}$
# $\displaystyle \begin{array}{r|l l l l l l l l l l l}
# 	{\scriptstyle i+j=0}&1&&&&&&&&&&\\
# 	{\scriptstyle i+j=2}&4&1&&&&&&&&&\\
# 	{\scriptstyle i+j=4}&9&5&1&&&&&&&&\\
# 	{\scriptstyle i+j=6}&15&14&5&1&&&&&&&\\
# 	{\scriptstyle i+j=8}&20&29&15&5&1&&&&&&\\
# 	{\scriptstyle i+j=10}&22&44&33&15&5&1&&&&&\\
# 	{\scriptstyle i+j=12}&20&51&54&34&15&5&1&&&&\\
# 	{\scriptstyle i+j=14}&15&46&66&58&34&15&5&1&&&\\
# 	{\scriptstyle i+j=16}&9&31&56&66&54&33&15&5&1&&\\
# 	{\scriptstyle i+j=18}&4&15&31&46&51&44&29&14&5&1&\\
# 	{\scriptstyle i+j=20}&1&4&9&15&20&22&20&15&9&4&1\\
# 	\hline h^{i,j}&{\scriptstyle j-i=0}&{\scriptstyle j-i=2}&{\scriptstyle j-i=4}&{\scriptstyle j-i=6}&{\scriptstyle j-i=8}&{\scriptstyle j-i=10}&{\scriptstyle j-i=12}&{\scriptstyle j-i=14}&{\scriptstyle j-i=16}&{\scriptstyle j-i=18}&{\scriptstyle j-i=20}
# \end{array}$
# $\displaystyle \begin{array}{rll}
# 	\text{module}&\text{multiplicity}&\text{dimension} \\ \hline \text{all}&&1296 \\
# 	\mathbb{C}&1296&1
# \end{array}$
#
# *** Profile stats marshalled to file 'prun.log'.
#          1518172817 function calls (1514186745 primitive calls) in 2506.831 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        30 1112.115   37.071 1684.716   56.157 quantum_center.py:166(Eijk_basis)
#        30  174.340    5.811  174.501    5.817 quantum_center.py:342(_quotient_basis_indices)
#     32658  137.402    0.004  141.377    0.004 {method 'solve_right' of 'sage.matrix.matrix2.Matrix' objects}
#       546  103.046    0.189  311.005    0.570 quantum_center.py:426(_compute_kernel)
#        90  100.875    1.121  310.869    3.454 la_modules.py:97(__init__)
#      3566   99.010    0.028  141.792    0.040 cohomology.pyx:325(coker_reduce)
#     29335   81.924    0.003  136.072    0.005 cohomology.pyx:75(merge_sorted_image)
#     17019   63.248    0.004   64.505    0.004 cohomology.pyx:20(compute_action)
#       180   55.855    0.310  207.757    1.154 la_modules.py:249(compute_weight_components)
#  41680619   47.643    0.000   47.643    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    144111   47.200    0.000   49.322    0.000 {method 'row' of 'sage.matrix.matrix1.Matrix' objects}
# 54172059/50298483   44.184    0.000  182.271    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        40   42.443    1.061   42.443    1.061 {method 'rank' of 'sage.matrix.matrix_integer_sparse.Matrix_integer_sparse' objects}
#  41667770   32.095    0.000   94.352    0.000 fromnumeric.py:69(_wrapreduction)
#      3566   27.640    0.008   39.370    0.011 cohomology.pyx:119(sort_cols)
#  83767056   27.428    0.000   34.952    0.000 stringsource:999(memoryview_fromslice)
#  41667589   20.873    0.000  108.549    0.000 fromnumeric.py:2404(all)
#      3566   20.455    0.006   37.093    0.010 cohomology.pyx:276(multiindex_to_index)
# 4625031/4579231   17.491    0.000   23.999    0.000 {built-in method builtins.sum}
#  41667589   15.793    0.000  141.546    0.000 <__array_function__ internals>:177(all)
# 182675841   14.074    0.000   14.074    0.000 free_module.py:2124(coordinate_ring)
#       527   13.641    0.026   13.756    0.026 {method 'stack' of 'sage.matrix.matrix1.Matrix' objects}
#   1824660   11.162    0.000   51.969    0.000 quantum_center.py:99(_sort_sign)
#  41667770    9.671    0.000    9.671    0.000 fromnumeric.py:70(<dictcomp>)
#   1755542    8.776    0.000    8.776    0.000 quantum_center.py:118(<listcomp>)
#   1755542    7.498    0.000    7.498    0.000 quantum_center.py:120(<listcomp>)
#  20895958    7.247    0.000   15.001    0.000 stringsource:403(__getitem__)
#      7133    6.795    0.001    7.075    0.001 {method 'augment' of 'sage.matrix.matrix_sparse.Matrix_sparse' objects}
# 110226305    6.262    0.000    6.262    0.000 stringsource:345(__cinit__)
#   2885775    6.031    0.000    6.031    0.000 weight_set.py:124(<genexpr>)
#   2134756    5.140    0.000    6.908    0.000 weight_set.py:152(dot_action)
# 110226305    5.128    0.000    5.128    0.000 stringsource:372(__dealloc__)
#         1    5.114    5.114 2506.903 2506.903 <string>:1(<module>)
#  42970607    5.099    0.000    5.099    0.000 {method 'items' of 'dict' objects}
#    116247    4.894    0.000    5.240    0.000 {method 'row' of 'sage.matrix.matrix_integer_dense.Matrix_integer_dense' objects}
#   3173814    4.832    0.000    4.832    0.000 {method 'sort' of 'numpy.ndarray' objects}
#  83767056    4.759    0.000    4.760    0.000 stringsource:976(__dealloc__)
#  26459249    4.578    0.000    6.988    0.000 stringsource:657(memoryview_cwrapper)
#     30269    4.383    0.000   14.990    0.000 weight_set.py:192(is_dot_regular)
#      3566    4.353    0.001    4.916    0.001 cohomology.pyx:292(dok_to_sage_sparse)
#  52185974    4.201    0.000    4.201    0.000 {method 'append' of 'list' objects}
#  84547004    4.144    0.000    4.144    0.000 cohomology.pyx:54(check_equal)
#   1824660    4.054    0.000    5.704    0.000 shape_base.py:23(atleast_1d)
#  41667589    3.937    0.000    3.937    0.000 fromnumeric.py:2399(_all_dispatcher)
#  81940162    3.855    0.000    3.855    0.000 stringsource:518(__getbuffer__)
#   3173814    3.829    0.000    3.829    0.000 {method 'copy' of 'numpy.ndarray' objects}
#    175571    3.698    0.000    3.793    0.000 matrix_space.py:819(_element_constructor_)
#  83763490    3.672    0.000    3.672    0.000 stringsource:559(__get__)
#     29335    2.968    0.000    2.968    0.000 cohomology.pyx:63(col_nonzero)
#  20895958    2.918    0.000    4.525    0.000 stringsource:393(get_item_pointer)
#   3379102    2.761    0.000   11.586    0.000 numeric.py:149(ones)
#   1824660    2.632    0.000   19.763    0.000 shape_base.py:285(hstack)
#   3489057    2.489    0.000    7.889    0.000 <__array_function__ internals>:177(copyto)
#   3173814    2.427    0.000   11.386    0.000 fromnumeric.py:852(sort)
#  20895958    2.306    0.000    2.306    0.000 stringsource:666(_unellipsify)
#   2149406    2.072    0.000    2.072    0.000 {built-in method numpy.array}
#    223570    2.025    0.000    2.186    0.000 free_module.py:1079(_element_constructor_)
#    994614    2.011    0.000    2.298    0.000 ambient_space.py:368(inner_product)
#  26356980    1.618    0.000    1.618    0.000 cohomology.pyx:107(permutation_sign)
#  20895958    1.607    0.000    1.607    0.000 stringsource:910(pybuffer_index)
#   3173814    1.589    0.000   14.429    0.000 <__array_function__ internals>:177(sort)
#   3379282    1.572    0.000    1.572    0.000 {built-in method numpy.empty}
#     29335    1.409    0.000  143.622    0.005 cohomology.pyx:102(sort_merge)
#        40    1.384    0.035   22.444    0.561 special.py:1746(block_matrix)
#   1938779    1.319    0.000    1.319    0.000 {built-in method numpy.zeros}
#  26462815    1.271    0.000    1.271    0.000 stringsource:663(memoryview_check)
#   1009410    1.176    0.000    4.004    0.000 root_lattice_realizations.py:3596(has_descent)
#   1895963    1.085    0.000   11.805    0.000 <__array_function__ internals>:177(concatenate)
#  11897232    0.990    0.000    0.990    0.000 {built-in method numpy.asanyarray}
#   1824660    0.979    0.000   23.156    0.000 <__array_function__ internals>:177(hstack)
#       180    0.938    0.005    0.938    0.005 la_modules.py:244(<listcomp>)
# 6832873/6832720    0.927    0.000    0.960    0.000 {built-in method builtins.len}
#  19072630    0.923    0.000    0.923    0.000 stringsource:979(convert_item_to_object)
#   1824660    0.834    0.000    7.354    0.000 <__array_function__ internals>:177(atleast_1d)
#    326575    0.767    0.000    2.042    0.000 matrix_space.py:513(__classcall__)
#    577088    0.695    0.000    4.535    0.000 root_lattice_realizations.py:3630(first_descent)
#     33728    0.694    0.000    1.374    0.000 weyl_group.py:810(action)
#    412560    0.640    0.000    0.640    0.000 {built-in method numpy.arange}
#   1825050    0.629    0.000    1.613    0.000 shape_base.py:218(_vhstack_dispatcher)
#    577088    0.595    0.000   13.521    0.000 weight_set.py:233(is_dominant)
#   1828616    0.588    0.000    0.990    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#     45604    0.526    0.000    0.929    0.000 {method 'bracket' of 'sage.algebras.lie_algebras.lie_algebra_element.StructureCoefficientsElement' objects}
#      3566    0.481    0.000  113.007    0.032 cohomology.pyx:136(action_on_basis)
#   3489057    0.473    0.000    0.473    0.000 multiarray.py:1071(copyto)
#        40    0.438    0.011   22.883    0.572 cohomology.pyx:301(assemble_block_diff)
#   3220221    0.435    0.000    0.436    0.000 {built-in method builtins.isinstance}
#   2003846    0.434    0.000    0.435    0.000 {built-in method builtins.hasattr}
#    326576    0.402    0.000    0.717    0.000 matrix_space.py:87(get_matrix_class)
#   3173814    0.398    0.000    0.398    0.000 fromnumeric.py:848(_sort_dispatcher)
#     31200    0.397    0.000    4.020    0.000 weight_set.py:97(weight_to_tuple)
#    223570    0.392    0.000    2.578    0.000 free_module.py:5825(_element_constructor_)
#    577155    0.372    0.000    8.174    0.000 weight_set.py:113(tuple_to_weight)
#    412846    0.365    0.000    0.365    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        40    0.347    0.009  589.329   14.733 cohomology.pyx:173(compute_diff)
#      8833    0.330    0.000   16.210    0.002 weight_set.py:248(make_dominant)
#    150279    0.321    0.000    0.337    0.000 free_module.py:2567(zero_vector)
#   1895963    0.296    0.000    0.296    0.000 multiarray.py:148(concatenate)
#     68326    0.263    0.000    0.273    0.000 {method '_vector_' of 'sage.modules.with_basis.indexed_element.IndexedFreeModuleElement' objects}
#    183565    0.252    0.000    0.630    0.000 root_lattice_realizations.py:235(_name_string_helper)
#      6433    0.245    0.000  311.251    0.048 quantum_center.py:404(__getitem__)
#    577088    0.218    0.000    4.753    0.000 root_lattice_realizations.py:3786(is_dominant)
#      8480    0.213    0.000    0.471    0.000 matrix_space.py:579(__init__)
#   1824660    0.196    0.000    0.196    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#   2720491    0.183    0.000    0.183    0.000 {method 'parent' of 'sage.structure.element.Element' objects}
#     50404    0.178    0.000    0.200    0.000 {method 'monomial_coefficients' of 'sage.algebras.lie_algebras.lie_algebra_element.StructureCoefficientsElement' objects}
#    109955    0.162    0.000    1.334    0.000 numeric.py:76(zeros_like)
#   1021168    0.162    0.000    0.168    0.000 family.py:746(__getitem__)
#        90    0.159    0.002  209.549    2.328 la_modules.py:291(initialize_weight_components)
#    183565    0.154    0.000    0.230    0.000 root_system.py:367(_repr_)
#     10375    0.145    0.000    0.330    0.000 homset.py:83(Hom)
#      9001    0.142    0.000    0.446    0.000 finite_enumerated_set.py:145(__contains__)
#    577115    0.139    0.000    0.139    0.000 root_lattice_realizations.py:213(index_set)
#      1870    0.128    0.000    0.665    0.000 matrix_space.py:996(_get_action_)
#     76554    0.124    0.000    0.167    0.000 fields.py:62(__contains__)
#      9057    0.123    0.000    0.404    0.000 {method 'index' of 'tuple' objects}
#       180    0.121    0.001    0.280    0.002 la_modules.py:124(<dictcomp>)
#        52    0.119    0.002    5.649    0.109 weight_set.py:126(get_action_dic)
#   1259925    0.107    0.000    0.107    0.000 {method 'base_ring' of 'sage.structure.category_object.CategoryObject' objects}
#    261450    0.104    0.000   54.666    0.000 matrix_misc.py:25(row_iterator)
#    183580    0.104    0.000    0.334    0.000 {built-in method builtins.repr}
#     96206    0.104    0.000    0.593    0.000 matrix_space.py:2073(matrix_space)
#        30    0.103    0.003  636.313   21.210 la_modules.py:1044(cohomology)
#     64330    0.103    0.000    0.529    0.000 {method 'transpose' of 'sage.matrix.matrix_rational_dense.Matrix_rational_dense' objects}
# 152403/152402    0.100    0.000    0.132    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#     10374    0.097    0.000    0.122    0.000 homset.py:583(__init__)
#    171624    0.095    0.000    0.139    0.000 <frozen importlib._bootstrap>:404(parent)
#     33728    0.095    0.000    0.095    0.000 free_module.py:917(<dictcomp>)
#       210    0.093    0.000    0.963    0.005 la_modules.py:754(adjoint_action_tensor)
#   1823328    0.091    0.000    0.091    0.000 stringsource:605(__len__)
#    632890    0.088    0.000    0.088    0.000 matrix_space.py:2108(nrows)
#    451170    0.086    0.000    0.105    0.000 la_modules.py:125(<genexpr>)
#     33728    0.084    0.000    0.286    0.000 free_module.py:899(from_vector)
#     72473    0.081    0.000    0.107    0.000 free_module.py:1095(_from_dict)
#    109955    0.078    0.000    0.447    0.000 <__array_function__ internals>:177(empty_like)
#       584    0.076    0.000    0.157    0.000 compute_maps.py:215(_multidegree_to_root_sum)
#   1019151    0.076    0.000    0.076    0.000 {method 'zero' of 'sage.rings.ring.Ring' objects}
# 12913/7767    0.075    0.000    0.861    0.000 pbw.py:367(product_on_basis)
#       121    0.073    0.001    0.073    0.001 libgap_mixin.py:606(__iter__)
#    153200    0.069    0.000    0.092    0.000 random.py:239(_randbelow_with_getrandbits)
#        30    0.069    0.002  136.104    4.537 quantum_center.py:327(<dictcomp>)
#    183565    0.067    0.000    0.697    0.000 root_space.py:95(_name_string)
#    109955    0.067    0.000    1.524    0.000 <__array_function__ internals>:177(zeros_like)
#     96533    0.067    0.000    0.085    0.000 indexed_free_monoid.py:504(__hash__)
#    632890    0.064    0.000    0.064    0.000 matrix_space.py:2096(ncols)
#        92    0.063    0.001    0.360    0.004 compute_maps.py:91(_get_available_problems)
#      1440    0.062    0.000    0.065    0.000 dynamic_class.py:339(dynamic_class_internal)
#       825    0.061    0.000    0.395    0.000 matrix_space.py:2217(_an_element_)
#      1441    0.060    0.000    0.074    0.000 weyl_group.py:689(__hash__)
#     30770    0.060    0.000    0.130    0.000 indexed_free_monoid.py:475(_sorted_items)
#     32486    0.060    0.000    0.149    0.000 verbose.py:116(verbose)
#    183566    0.059    0.000    0.059    0.000 cartan_type.py:2411(_repr_)
#    153200    0.059    0.000    0.160    0.000 random.py:292(randrange)
#     45800    0.057    0.000    0.120    0.000 digraph.py:1162(outgoing_edges)
# 9925/9903    0.057    0.000    0.641    0.000 {sage.misc.classcall_metaclass.typecall}
#    183565    0.056    0.000    0.754    0.000 root_space.py:79(_repr_)
#    408449    0.052    0.000    0.052    0.000 free_module.py:2036(degree)
#     23814    0.052    0.000    0.411    0.000 root_space.py:234(scalar)
#      3624    0.049    0.000    0.158    0.000 la_modules.py:912(root_to_latex)
#        20    0.049    0.002    0.862    0.043 compute_maps.py:73(_compute_initial_maps)
#       180    0.048    0.000    0.052    0.000 numeric.py:1680(indices)
#     32486    0.044    0.000    0.044    0.000 {built-in method resource.getrusage}
#    171698    0.044    0.000    0.044    0.000 {method 'rpartition' of 'str' objects}
#        30    0.044    0.001   31.248    1.042 weight_set.py:211(compute_weights)
#       270    0.043    0.000    0.051    0.000 la_modules.py:314(get_action_tensor)
#       734    0.042    0.000    0.042    0.000 {built-in method builtins.dir}
# 15731/12123    0.041    0.000    1.455    0.000 {built-in method sage.data_structures.blas_dict.linear_combination}
#     21431    0.040    0.000    0.107    0.000 dynamic_class.py:129(dynamic_class)
#     32486    0.039    0.000    0.089    0.000 misc.py:288(cputime)
#     69384    0.038    0.000    0.046    0.000 weyl_group.py:705(domain)
#      8631    0.037    0.000    0.169    0.000 modules.py:114(__classcall_private__)
#     40441    0.037    0.000    0.038    0.000 rational_field.py:1130(some_elements)
#    252437    0.036    0.000    0.056    0.000 la_modules.py:116(<genexpr>)
#     83374    0.036    0.000    0.036    0.000 weakref.py:353(__init__)
# 135700/118651    0.036    0.000    0.078    0.000 {built-in method builtins.getattr}
#       575    0.035    0.000    0.037    0.000 matrix_space.py:1908(zero_matrix)
#     31820    0.034    0.000    0.034    0.000 {method 'list' of 'sage.matrix.matrix0.Matrix' objects}
#     69614    0.033    0.000    0.297    0.000 root_space.py:271(<genexpr>)
#     12118    0.033    0.000    0.130    0.000 category.py:418(__classcall__)
#        90    0.033    0.000    0.112    0.001 la_modules.py:115(<dictcomp>)
#     45800    0.032    0.000    0.164    0.000 dynkin_diagram.py:778(column)
#      9183    0.032    0.000    0.072    0.000 matrix_space.py:1109(_coerce_map_from_)
#     86094    0.029    0.000    0.050    0.000 weakref.py:348(__new__)
#     71576    0.028    0.000    0.028    0.000 compute_maps.py:106(<listcomp>)
#       151    0.027    0.000    0.762    0.005 la_modules.py:597(__init__)
#       825    0.027    0.000    0.117    0.000 {method 'matrix' of 'sage.matrix.args.MatrixArgs' objects}
#     21169    0.027    0.000    0.064    0.000 free_module.py:997(_monomial)
#       892    0.027    0.000    0.066    0.000 free_module.py:768(__init__)
#     45604    0.026    0.000    0.048    0.000 structure_coefficients.py:283(dimension)
#      3566    0.025    0.000    0.099    0.000 shape_base.py:357(stack)
#       312    0.025    0.000    0.029    0.000 std.py:355(format_meter)
#       656    0.025    0.000    0.090    0.000 traitlets.py:276(getmembers)
# 23834/15080    0.024    0.000    0.878    0.000 magmatic_algebras.py:215(<genexpr>)
#      8263    0.023    0.000    0.023    0.000 quantum_center.py:421(__contains__)
#      8605    0.023    0.000    0.032    0.000 category.py:2506(category)
#     45800    0.023    0.000    0.064    0.000 digraph.py:1134(outgoing_edge_iterator)
#      4128    0.022    0.000    0.034    0.000 misc.py:1193(previous_prime)
#     76449    0.022    0.000    0.030    0.000 {built-in method builtins.all}
#     86776    0.021    0.000    0.021    0.000 {built-in method __new__ of type object at 0x7f20bbe0d020}
#    183991    0.021    0.000    0.021    0.000 matrix_space.py:1856(is_sparse)
#     29515    0.021    0.000    0.040    0.000 fromnumeric.py:51(_wrapfunc)
#     69129    0.020    0.000    0.020    0.000 pbw.py:147(_basis_key)
#     24209    0.020    0.000    0.089    0.000 poor_man_map.py:245(__call__)
# 9923/9903    0.020    0.000    0.663    0.000 unique_representation.py:992(__classcall__)
#     31426    0.020    0.000    0.055    0.000 {method 'sort' of 'list' objects}
#     29515    0.020    0.000    0.093    0.000 <__array_function__ internals>:177(transpose)
#     45811    0.020    0.000    0.033    0.000 generic_graph.py:10376(has_vertex)
#     57542    0.020    0.000    0.028    0.000 free_module.py:550(__contains__)
# 143962/143961    0.020    0.000    0.020    0.000 {built-in method builtins.hash}
#     12849    0.019    0.000    0.045    0.000 numeric.py:2388(array_equal)
#     48309    0.019    0.000    0.035    0.000 pbw.py:196(_monoid_key)
#     29515    0.018    0.000   12.629    0.000 <__array_function__ internals>:177(lexsort)
#        90    0.018    0.000    0.220    0.002 la_modules.py:805(coadjoint_action_tensor)
#     45604    0.018    0.000    0.021    0.000 family.py:721(cardinality)
#      2451    0.017    0.000    0.100    0.000 free_module.py:287(FreeModule)
#     25769    0.017    0.000  135.247    0.005 {bggcohomology.cohomology.sort_merge}
#     29515    0.017    0.000    0.057    0.000 fromnumeric.py:601(transpose)
# 15731/12123    0.016    0.000    1.474    0.000 free_module.py:945(linear_combination)
#    183747    0.016    0.000    0.016    0.000 root_system.py:381(cartan_type)
#     40507    0.016    0.000    0.016    0.000 enumerated_sets.py:823(_some_elements_from_iterator)
#      9001    0.016    0.000    0.900    0.000 indexed_free_monoid.py:979(gen)
#      4810    0.016    0.000    0.606    0.000 morphism.py:380(__call__)
#     13710    0.015    0.000    0.018    0.000 compute_maps.py:234(<genexpr>)
#     34800    0.015    0.000    0.029    0.000 la_modules.py:786(<dictcomp>)
#     33748    0.015    0.000    0.015    0.000 free_module.py:1150(<dictcomp>)
#        40    0.015    0.000    0.029    0.001 weight_set.py:274(get_vertex_weights)
# 10921/7313    0.015    0.000    0.934    0.000 magmatic_algebras.py:201(_product_from_product_on_basis_multiply)
#    183568    0.015    0.000    0.015    0.000 {method 'strip' of 'str' objects}
# 33464/24710    0.015    0.000    1.413    0.000 free_module.py:969(<genexpr>)
#       180    0.015    0.000    1.624    0.009 la_modules.py:173(construct_component)
#    183664    0.015    0.000    0.015    0.000 {method 'upper' of 'str' objects}
#    109955    0.015    0.000    0.015    0.000 numeric.py:72(_zeros_like_dispatcher)
#    221355    0.015    0.000    0.015    0.000 {method 'getrandbits' of '_random.Random' objects}
#     26420    0.014    0.000    0.034    0.000 indexed_free_monoid.py:593(__len__)
#      9950    0.014    0.000    0.096    0.000 indexed_free_monoid.py:336(to_word_list)
#      9950    0.014    0.000    0.014    0.000 indexed_free_monoid.py:355(<listcomp>)
#     20129    0.014    0.000    0.021    0.000 enumerated_sets.py:394(__getitem__)
#      5484    0.014    0.000    0.097    0.000 root_lattice_realizations.py:1473(<lambda>)
#      2075    0.013    0.000    0.014    0.000 weyl_group.py:678(__init__)
#     23020    0.013    0.000    0.023    0.000 indexed_free_monoid.py:459(__init__)
#     32326    0.013    0.000    0.017    0.000 indexed_free_monoid.py:205(_richcmp_)
#     33842    0.013    0.000    0.013    0.000 {method 'base_ring' of 'sage.structure.element.Element' objects}
#       620    0.012    0.000    0.104    0.000 bggcomplex.py:328(_weight_to_tuple)
#     45800    0.012    0.000    0.012    0.000 dynkin_diagram.py:791(<listcomp>)
#    109955    0.012    0.000    0.012    0.000 multiarray.py:80(empty_like)
#     10410    0.012    0.000    0.028    0.000 indexed_free_monoid.py:516(_mul_)
# 14750/10936    0.011    0.000    0.027    0.000 category.py:3048(is_subcategory)
#      9001    0.011    0.000    0.427    0.000 finite_enumerated_set.py:300(__call__)
# 24607/23014    0.011    0.000    0.057    0.000 traitlets.py:643(get)
#      9170    0.011    0.000    0.011    0.000 {built-in method sage.rings.ring._is_Field}
#     23985    0.011    0.000    0.011    0.000 root_system.py:458(root_lattice)
#      2384    0.011    0.000    0.018    0.000 encoder.py:204(iterencode)
#       655    0.011    0.000    0.017    0.000 traitlets.py:1781(<listcomp>)
#     23020    0.010    0.000    0.010    0.000 indexed_free_monoid.py:52(__init__)
#       540    0.010    0.000    0.029    0.000 la_modules.py:751(<listcomp>)
#     53999    0.010    0.000    0.010    0.000 {method 'monomial_coefficients' of 'sage.modules.with_basis.indexed_element.IndexedFreeModuleElement' objects}
# 45030/37372    0.010    0.000    0.066    0.000 traitlets.py:675(__get__)
#     33728    0.010    0.000    0.010    0.000 {method 'items' of 'sage.modules.free_module_element.FreeModuleElement' objects}
#     30785    0.010    0.000    0.010    0.000 indexed_generators.py:201(print_options)
#     29515    0.010    0.000    0.019    0.000 multiarray.py:416(lexsort)
#        48    0.009    0.000    0.009    0.000 {method '__exit__' of '_io._IOBase' objects}
# 2445/1677    0.009    0.000    0.034    0.000 category_with_axiom.py:1967(__classcall__)
#    153200    0.009    0.000    0.009    0.000 {built-in method _operator.index}
# 1804/1771    0.009    0.000    0.014    0.000 traitlets.py:1388(_notify_observers)
#         1    0.009    0.009    0.080    0.080 bggcomplex.py:177(_construct_BGG_graph)
#     29515    0.009    0.000    0.009    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     65442    0.009    0.000    0.009    0.000 indexed_free_monoid.py:608(<genexpr>)
#     57560    0.009    0.000    0.009    0.000 {built-in method sage.structure.element.parent}
#     69633    0.008    0.000    0.008    0.000 weyl_group.py:447(domain)
#     45800    0.008    0.000    0.008    0.000 {method 'has_vertex' of 'sage.graphs.base.c_graph.CGraphBackend' objects}
#        31    0.008    0.000    0.008    0.000 {built-in method io.open}
#     29789    0.008    0.000    0.008    0.000 compute_signs.py:56(_total_sign)
#      9393    0.008    0.000    0.008    0.000 additive_magmas.py:207(__init_extra__)
#         1    0.008    0.008    0.008    0.008 libgap_mixin.py:181(is_finite)
#    153200    0.008    0.000    0.008    0.000 {method 'bit_length' of 'int' objects}
#      7620    0.008    0.000    0.483    0.000 call.py:34(__call__)
#     45808    0.008    0.000    0.008    0.000 {method 'iterator_out_edges' of 'sage.graphs.base.c_graph.CGraphBackend' objects}
#      3344    0.008    0.000    0.341    0.000 image_set.py:192(__iter__)
#       767    0.008    0.000    0.050    0.000 {method '_generic_coerce_map' of 'sage.structure.parent.Parent' objects}
#      1426    0.008    0.000    0.083    0.000 category.py:449(__init__)
#       770    0.008    0.000    0.012    0.000 magmas.py:814(__init_extra__)
#     23826    0.008    0.000    0.025    0.000 root_lattice_realizations.py:1203(coroot_lattice)
#      4580    0.007    0.000    0.360    0.000 root_lattice_realizations.py:3668(<listcomp>)
#       621    0.007    0.000    0.007    0.000 socket.py:543(send)
#     23827    0.007    0.000    0.017    0.000 root_system.py:512(coroot_lattice)
#     17764    0.007    0.000    0.007    0.000 {method 'is_prime' of 'sage.rings.integer.Integer' objects}
#      4800    0.007    0.000    0.010    0.000 triangular_kac_moody_algebras.py:142(f)
#      3608    0.007    0.000    0.014    0.000 indexed_free_monoid.py:555(__floordiv__)
#      4800    0.007    0.000    0.154    0.000 {built-in method sage.arith.power.generic_power}
#       891    0.007    0.000    0.077    0.000 free_module.py:240(create_object)
#     13345    0.006    0.000    0.011    0.000 category.py:647(_subcategory_hook_)
#      7140    0.006    0.000    0.008    0.000 {built-in method builtins.sorted}
#     17645    0.006    0.000    0.015    0.000 rational_field.py:1684(is_RationalField)
#     10410    0.006    0.000    0.044    0.000 indexed_free_monoid.py:314(trailing_support)
#       880    0.006    0.000    0.021    0.000 {method '_coerce_map_via' of 'sage.structure.parent.Parent' objects}
#        20    0.006    0.000    1.232    0.062 compute_maps.py:176(solve)
#      1110    0.006    0.000    0.010    0.000 la_modules.py:696(<listcomp>)
#       685    0.006    0.000    0.006    0.000 {method 'acquire' of '_thread.lock' objects}
#        30    0.006    0.000    0.006    0.000 {built-in method _pickle.dump}
#      2686    0.006    0.000    0.006    0.000 misc.py:1883(xgcd)
#      1084    0.006    0.000    0.088    0.000 compute_maps.py:230(_partition_to_PBW)
#        20    0.006    0.000  636.130   31.806 la_modules.py:1004(cohomology_component)
#      3566    0.006    0.000    0.131    0.000 <__array_function__ internals>:177(stack)
#     12849    0.006    0.000    0.057    0.000 <__array_function__ internals>:177(array_equal)
#      3232    0.006    0.000    0.010    0.000 integer_mod_ring.py:197(get_object)
#       152    0.006    0.000    0.012    0.000 image_set.py:43(__init__)
#      3632    0.006    0.000    0.010    0.000 structure_coefficients.py:320(monomial)
#     10410    0.006    0.000    0.006    0.000 {built-in method sage.data_structures.blas_dict.add}
#       546    0.006    0.000    0.143    0.000 special.py:888(identity_matrix)
#      5496    0.006    0.000    0.103    0.000 root_lattice_realizations.py:3398(simple_reflection)
#       620    0.006    0.000    0.007    0.000 weyl_group.py:959(apply_simple_reflection)
#      3566    0.005    0.000    0.005    0.000 shape_base.py:424(<setcomp>)
#       292    0.005    0.000    0.029    0.000 compute_maps.py:255(_vectorize_polynomials_list)
#      9001    0.005    0.000    0.413    0.000 finite_enumerated_set.py:380(_element_constructor_)
#     13680    0.005    0.000    0.005    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       596    0.005    0.000    0.077    0.000 session.py:751(send)
#       892    0.005    0.000    0.007    0.000 free_module.py:7474(element_class)
#     17764    0.005    0.000    0.012    0.000 misc.py:472(is_prime)
#     15436    0.005    0.000    0.005    0.000 {built-in method builtins.issubclass}
#      4800    0.005    0.000    0.519    0.000 pbw.py:302(basis_function)
#      1376    0.005    0.000    0.007    0.000 compute_maps.py:287(<genexpr>)
#      4580    0.005    0.000    0.474    0.000 root_lattice_realizations.py:3883(pred)
#     29515    0.005    0.000    0.005    0.000 fromnumeric.py:597(_transpose_dispatcher)
#         1    0.005    0.005    0.006    0.006 weyl_group.py:220(__init__)
#      1192    0.005    0.000    0.005    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#      2536    0.005    0.000    0.011    0.000 vector_spaces.py:39(__classcall_private__)
#      3566    0.005    0.000    0.005    0.000 shape_base.py:432(<listcomp>)
#     45760    0.005    0.000    0.005    0.000 {method 'is_exact' of 'sage.rings.ring.Ring' objects}
#       661    0.005    0.000    0.007    0.000 la_modules.py:721(<listcomp>)
#      9630    0.005    0.000    0.524    0.000 morphism.py:405(<genexpr>)
#       620    0.005    0.000    0.011    0.000 bggcomplex.py:332(<listcomp>)
#     58820    0.005    0.000    0.005    0.000 {method 'keys' of 'dict' objects}
#       655    0.005    0.000    0.112    0.000 traitlets.py:1766(traits)
#     10268    0.005    0.000    0.005    0.000 la_modules.py:934(<genexpr>)
#      3271    0.005    0.000    0.005    0.000 {method 'format' of 'str' objects}
#       306    0.005    0.000    0.005    0.000 {method 'split' of 're.Pattern' objects}
#      1928    0.004    0.000    0.126    0.000 weyl_group.py:845(has_descent)
#     23822    0.004    0.000    0.005    0.000 root_lattice_realizations.py:223(dynkin_diagram)
#       422    0.004    0.000    0.045    0.000 matrix_space.py:752(transposed)
#     10410    0.004    0.000    0.029    0.000 indexed_free_monoid.py:292(leading_support)
#     20129    0.004    0.000    0.004    0.000 finite_enumerated_set.py:278(unrank)
#      3566    0.004    0.000    0.010    0.000 shape_base.py:348(_stack_dispatcher)
#        40    0.004    0.000    0.006    0.000 special.py:1535(_determine_block_matrix_grid)
#      9001    0.004    0.000    0.408    0.000 finite_enumerated_set.py:264(rank)
#      3566    0.004    0.000    0.015    0.000 shape_base.py:420(<listcomp>)
#       292    0.004    0.000    0.839    0.003 compute_maps.py:263(_solve_problem)
#      2384    0.004    0.000    0.028    0.000 __init__.py:183(dumps)
#       896    0.004    0.000    0.010    0.000 misc.py:3338(<listcomp>)
#     32329    0.004    0.000    0.004    0.000 {built-in method sage.structure.richcmp.rich_to_bool}
#       307    0.004    0.000    0.242    0.001 notebook.py:149(display)
#      3020    0.004    0.000    0.007    0.000 la_modules.py:658(dic_to_vec)
#     12849    0.004    0.000    0.023    0.000 {method 'all' of 'numpy.ndarray' objects}
#      2451    0.004    0.000    0.004    0.000 free_module.py:217(create_key)
#     16008    0.004    0.000    0.004    0.000 family.py:812(__getitem__)
#      3100    0.003    0.000    0.004    0.000 bggcomplex.py:349(<genexpr>)
#       768    0.003    0.000    0.061    0.000 unital_algebras.py:71(__init_extra__)
#       596    0.003    0.000    0.203    0.000 widget.py:676(notify_change)
#       596    0.003    0.000    0.045    0.000 session.py:687(serialize)
#     12849    0.003    0.000    0.020    0.000 _methods.py:60(_all)
#      2457    0.003    0.000    0.019    0.000 compute_maps.py:241(_monomial_to_tuple)
#     26235    0.003    0.000    0.003    0.000 {method 'get' of 'dict' objects}
#      3232    0.003    0.000    0.003    0.000 {function IntegerModFactory.get_object at 0x7f209c699090}
#       896    0.003    0.000    0.009    0.000 matrix_space.py:931(change_ring)
#       590    0.003    0.000    0.084    0.000 comm.py:66(_publish_msg)
#       540    0.003    0.000    0.005    0.000 la_modules.py:746(<listcomp>)
#     16479    0.003    0.000    0.003    0.000 {sage.rings.integer_ring.is_IntegerRing}
# 1437/1426    0.003    0.000    0.004    0.000 category.py:2710(_make_named_class)
#      2384    0.003    0.000    0.022    0.000 encoder.py:182(encode)
#        90    0.003    0.000  312.467    3.472 quantum_center.py:55(Mjk)
#      4580    0.003    0.000    0.106    0.000 root_lattice_realizations.py:3908(<listcomp>)
#       770    0.003    0.000    0.018    0.000 rings.py:382(_Hom_)
#     20749    0.003    0.000    0.003    0.000 homset.py:748(homset_category)
#     23320    0.003    0.000    0.003    0.000 {method 'issubset' of 'set' objects}
# 16704/16686    0.003    0.000    0.006    0.000 {built-in method builtins.next}
#      1928    0.003    0.000    0.009    0.000 ambient_space.py:408(is_positive_root)
#       270    0.003    0.000    1.130    0.004 la_modules.py:849(build_component)
#      6599    0.003    0.000    0.008    0.000 {method 'join' of 'str' objects}
#     38547    0.003    0.000    0.003    0.000 {built-in method numpy.asarray}
#      2384    0.003    0.000    0.031    0.000 session.py:97(json_packer)
#        52    0.003    0.000    5.669    0.109 weight_set.py:60(__init__)
#      1425    0.003    0.000    0.085    0.000 groupoid.py:33(__init__)
#     12209    0.003    0.000    0.003    0.000 compute_maps.py:243(<genexpr>)
#     30850    0.003    0.000    0.003    0.000 {sage.structure.element.is_Matrix}
#     10140    0.003    0.000    0.003    0.000 {method 'category' of 'sage.rings.ring.Ring' objects}
#        78    0.003    0.000    0.008    0.000 traitlets.py:1186(setup_instance)
#      4580    0.003    0.000    0.363    0.000 root_lattice_realizations.py:3655(descents)
#      1108    0.003    0.000    0.004    0.000 traitlets.py:1715(_get_trait_default_generator)
# 3631/3619    0.003    0.000    0.004    0.000 copy.py:66(copy)
#       768    0.003    0.000    0.014    0.000 homset.py:39(RingHomset)
#       151    0.003    0.000    0.007    0.000 la_modules.py:611(<dictcomp>)
#       151    0.003    0.000    0.007    0.000 la_modules.py:613(<dictcomp>)
#      1895    0.003    0.000    0.005    0.000 traitlets.py:1799(trait_metadata)
#     10376    0.002    0.000    0.002    0.000 homset.py:1173(domain)
#       896    0.002    0.000    0.014    0.000 misc.py:3297(CRT_basis)
#        30    0.002    0.000    0.273    0.009 quantum_center.py:126(compute_phi)
#   589/568    0.002    0.000    0.150    0.000 widget.py:557(get_state)
#       151    0.002    0.000    0.008    0.000 la_modules.py:628(<listcomp>)
#      3981    0.002    0.000    0.016    0.000 compute_signs.py:60(_check_choice)
#     11836    0.002    0.000    0.002    0.000 integer_mod_ring.py:1105(order)
#       661    0.002    0.000    0.002    0.000 la_modules.py:726(<listcomp>)
#      3644    0.002    0.000    0.003    0.000 sequence.py:505(__getitem__)
#      1426    0.002    0.000    0.006    0.000 category.py:1605(subcategory_class)
# 2406/2377    0.002    0.000    0.014    0.000 traitlets.py:717(_validate)
#       151    0.002    0.000    0.161    0.001 la_modules.py:622(<dictcomp>)
#       312    0.002    0.000    0.006    0.000 std.py:1460(format_dict)
# 1280/1236    0.002    0.000    0.215    0.000 traitlets.py:688(set)
#     13496    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#         1    0.002    0.002    0.021    0.021 compute_signs.py:21(compute_signs)
# 1209/1198    0.002    0.000    0.009    0.000 traitlets.py:726(_cross_validate)
#     21171    0.002    0.000    0.002    0.000 {method 'one' of 'sage.rings.ring.Ring' objects}
#       768    0.002    0.000    0.005    0.000 magmatic_algebras.py:171(product)
#        67    0.002    0.000    0.007    0.000 weight_set.py:291(highest_weight_rep_dim)
#       556    0.002    0.000    0.186    0.000 widget.py:538(send_state)
#      2892    0.002    0.000    0.002    0.000 dynamic_class.py:438(<genexpr>)
#       621    0.002    0.000    0.011    0.000 iostream.py:202(schedule)
#      5349    0.002    0.000    0.007    0.000 category.py:3046(<genexpr>)
#       292    0.002    0.000    0.018    0.000 compute_maps.py:245(_vectorize_polynomial)
#     10376    0.002    0.000    0.002    0.000 homset.py:1188(codomain)
#      1814    0.002    0.000    0.061    0.000 free_module.py:1046(sum_of_terms)
#       152    0.002    0.000    0.014    0.000 weyl_group.py:60(WeylGroup)
#      1814    0.002    0.000    0.057    0.000 {built-in method sage.data_structures.blas_dict.sum_of_terms}
#      4800    0.002    0.000    0.155    0.000 monoids.py:255(_pow_int)
#       596    0.002    0.000    0.009    0.000 session.py:672(sign)
#      5451    0.002    0.000    0.002    0.000 bunch.py:13(__getattr__)
#       768    0.002    0.000    0.002    0.000 {method 'register_coercion' of 'sage.structure.parent.Parent' objects}
#      1535    0.002    0.000    0.009    0.000 category.py:3025(_subcategory_hook_)
#       620    0.002    0.000    0.112    0.000 bggcomplex.py:337(_weight_to_alpha_sum)
#       302    0.002    0.000    0.009    0.000 {sage.modules.free_module_element.vector}
#      2384    0.002    0.000    0.002    0.000 {method 'update' of '_hashlib.HMAC' objects}
#      2384    0.002    0.000    0.002    0.000 encoder.py:104(__init__)
#      1562    0.002    0.000    0.012    0.000 category.py:691(__contains__)
#       596    0.002    0.000    0.002    0.000 session.py:599(msg_id)
#      1321    0.002    0.000    0.002    0.000 weyl_group.py:774(__eq__)
#  1108/303    0.002    0.000    0.045    0.000 traitlets.py:1740(trait_defaults)
#      3981    0.002    0.000    0.002    0.000 compute_signs.py:61(<listcomp>)
#        20    0.001    0.000    4.284    0.214 bggcomplex.py:264(compute_maps)
#       596    0.001    0.000    0.010    0.000 session.py:646(msg)
#      7948    0.001    0.000    0.001    0.000 sets_cat.py:1892(is_finite)
#      5414    0.001    0.000    0.003    0.000 category.py:2578(is_Category)
#       596    0.001    0.000    0.001    0.000 {method 'replace' of 'datetime.datetime' objects}
#   604/589    0.001    0.000    0.002    0.000 widget.py:93(_separate_buffers)
#      1110    0.001    0.000    0.012    0.000 la_modules.py:679(parabolic_p_basis)
#       742    0.001    0.000    0.128    0.000 coxeter_groups.py:1395(first_descent)
#        20    0.001    0.000    0.008    0.000 weight_set.py:190(<dictcomp>)
#     14531    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      1192    0.001    0.000    0.008    0.000 jsonutil.py:108(json_default)
#      3566    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#     10775    0.001    0.000    0.001    0.000 {method 'base' of 'sage.structure.category_object.CategoryObject' objects}
#     12849    0.001    0.000    0.001    0.000 numeric.py:2384(_array_equal_dispatcher)
#         1    0.001    0.001    0.491    0.491 bggcomplex.py:90(__init__)
#       768    0.001    0.000    0.010    0.000 homset.py:1232(__init__)
#         1    0.001    0.001    0.019    0.019 classical_lie_algebra.py:1574(__init__)
#       554    0.001    0.000    0.004    0.000 type_A.py:71(root)
#      3959    0.001    0.000    0.002    0.000 matrix_space.py:68(is_MatrixSpace)
#       151    0.001    0.000    0.006    0.000 kac_moody_algebras.py:70(weyl_group)
#   696/663    0.001    0.000    0.205    0.000 traitlets.py:1373(_notify_trait)
#       339    0.001    0.000    0.001    0.000 compute_signs.py:85(<genexpr>)
#       343    0.001    0.000    0.074    0.000 std.py:1212(update)
#       152    0.001    0.000    0.014    0.000 enumerated_sets.py:871(map)
#       302    0.001    0.000    0.241    0.001 std.py:1339(refresh)
#     11207    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#       596    0.001    0.000    0.001    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#   154/153    0.001    0.000    0.001    0.000 root_system.py:300(__classcall__)
#       556    0.001    0.000    0.080    0.000 widget.py:814(_send)
#       152    0.001    0.000    0.181    0.001 enumerated_sets.py:464(__len__)
#       661    0.001    0.000    0.011    0.000 la_modules.py:704(parabolic_n_basis)
#       891    0.001    0.000    0.067    0.000 free_module.py:4776(__init__)
#      1403    0.001    0.000    0.002    0.000 {built-in method builtins.max}
#      4571    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#       596    0.001    0.000    0.002    0.000 hmac.py:122(copy)
#       405    0.001    0.000    0.001    0.000 free_module.py:4836(_coerce_map_from_)
#       312    0.001    0.000    0.003    0.000 notebook.py:200(colour)
#       262    0.001    0.000    0.495    0.002 compute_maps.py:271(<listcomp>)
#       729    0.001    0.000    0.001    0.000 std.py:233(__call__)
#       390    0.001    0.000    0.001    0.000 shape_base.py:81(atleast_2d)
#        30    0.001    0.000    0.001    0.000 la_modules.py:1074(<listcomp>)
#       596    0.001    0.000    0.001    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#      9972    0.001    0.000    0.001    0.000 {method 'index' of 'list' objects}
#       896    0.001    0.000    0.001    0.000 {sage.misc.misc_c.prod}
#      3232    0.001    0.000    0.001    0.000 integer_mod_ring.py:205(create_key_and_extra_args)
#       310    0.001    0.000    0.001    0.000 std.py:104(acquire)
#       891    0.001    0.000    0.069    0.000 free_module.py:5643(__init__)
#       768    0.001    0.000    0.011    0.000 homset.py:70(__init__)
#       633    0.001    0.000    0.002    0.000 threading.py:1169(is_alive)
#       180    0.001    0.000    6.678    0.037 fromnumeric.py:2160(sum)
#       152    0.001    0.000    0.015    0.000 root_lattice_realizations.py:1182(negative_roots)
#       556    0.001    0.000    0.004    0.000 widget.py:724(_should_send_property)
#       596    0.001    0.000    0.013    0.000 iostream.py:283(send_multipart)
# 1241/1197    0.001    0.000    0.216    0.000 traitlets.py:706(__set__)
#      3632    0.001    0.000    0.001    0.000 free_module.py:5128(basis)
#       120    0.001    0.000    0.104    0.001 bggcomplex.py:142(<dictcomp>)
#       151    0.001    0.000    0.001    0.000 la_modules.py:629(<listcomp>)
#      2384    0.001    0.000    0.003    0.000 hmac.py:117(update)
#      1219    0.001    0.000    0.001    0.000 contextlib.py:102(__init__)
#        52    0.001    0.000    0.005    0.000 type_A.py:112(positive_roots)
#      3025    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#       292    0.001    0.000    0.088    0.000 compute_maps.py:265(<listcomp>)
#      6653    0.001    0.000    0.001    0.000 {built-in method builtins.abs}
#       229    0.001    0.000    0.002    0.000 rational_field.py:340(_coerce_map_from_)
#      2373    0.001    0.000    0.054    0.000 pbw.py:436(<genexpr>)
#       343    0.001    0.000    0.075    0.000 notebook.py:268(update)
#       596    0.001    0.000    0.008    0.000 session.py:643(msg_header)
#       891    0.001    0.000    0.068    0.000 free_module.py:5473(__init__)
#         1    0.001    0.001    0.007    0.007 bggcomplex.py:164(<dictcomp>)
#       452    0.001    0.000    0.002    0.000 std.py:288(format_interval)
#      2686    0.001    0.000    0.001    0.000 quotient_ring.py:911(cover_ring)
#       596    0.001    0.000    0.001    0.000 session.py:846(<listcomp>)
#       152    0.001    0.000    0.001    0.000 image_set.py:178(cardinality)
#       596    0.001    0.000    0.003    0.000 session.py:201(utcnow)
#       767    0.001    0.000    0.051    0.000 matrix_space.py:1071(_coerce_map_from_base_ring)
#      3232    0.001    0.000    0.001    0.000 verbose.py:251(get_verbose)
#       310    0.001    0.000    0.001    0.000 std.py:108(release)
#      6644    0.001    0.000    0.001    0.000 la_modules.py:933(<lambda>)
#        52    0.001    0.000    0.002    0.000 weight_set.py:82(<listcomp>)
#       245    0.001    0.000    0.001    0.000 {method 'has_coerce_map_from' of 'sage.structure.parent.Parent' objects}
#       768    0.001    0.000    0.001    0.000 {method '_make_weak_references' of 'sage.categories.map.Map' objects}
#       540    0.001    0.000    0.035    0.000 la_modules.py:729(parabolic_u_basis)
#       720    0.001    0.000    0.132    0.000 coxeter_groups.py:1503(reduced_word_reverse_iterator)
#       156    0.001    0.000    0.001    0.000 {built-in method sage.categories.category_cy_helper._sort_uniq}
#      4207    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#       556    0.001    0.000    0.078    0.000 comm.py:135(send)
#      8415    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#       590    0.001    0.000    0.001    0.000 kernelbase.py:617(get_parent)
#       612    0.001    0.000    0.001    0.000 __init__.py:12(escape)
#       155    0.001    0.000    0.001    0.000 category_with_axiom.py:2007(__classget__)
#       165    0.001    0.000    0.001    0.000 category.py:709(__classcontains__)
#       102    0.001    0.000    0.001    0.000 ambient_space.py:259(<lambda>)
#      16/1    0.001    0.000 2506.903 2506.903 {built-in method builtins.exec}
#       252    0.001    0.000    0.001    0.000 classical_lie_algebra.py:1796(_basis_key)
#        15    0.001    0.000    0.001    0.000 {built-in method marshal.loads}
#        32    0.001    0.000   34.760    1.086 la_modules.py:976(__init__)
#       621    0.001    0.000    0.001    0.000 iostream.py:90(_event_pipe)
#       180    0.001    0.000    6.679    0.037 <__array_function__ internals>:177(sum)
#       181    0.001    0.000    0.001    0.000 poor_man_map.py:60(__init__)
#       153    0.001    0.000    0.002    0.000 cartan_type.py:1448(root_system)
#       596    0.001    0.000    0.012    0.000 iostream.py:214(send_multipart)
#   505/494    0.001    0.000    0.013    0.000 traitlets.py:1129(__call__)
#       309    0.001    0.000    0.001    0.000 re.py:288(_compile)
#       596    0.001    0.000    0.004    0.000 session.py:273(msg_header)
#      1197    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#      5467    0.001    0.000    0.001    0.000 {method '__getitem__' of 'dict' objects}
#       462    0.001    0.000    0.037    0.000 free_module.py:5735(__init__)
# 1219/1210    0.001    0.000    0.002    0.000 contextlib.py:139(__exit__)
#        10    0.001    0.000    0.010    0.001 weyl_group.py:379(to_elt)
#         1    0.001    0.001    0.001    0.001 compute_signs.py:39(<listcomp>)
#      1186    0.001    0.000    0.001    0.000 jsonutil.py:77(json_clean)
#       292    0.001    0.000    0.001    0.000 compute_maps.py:275(<dictcomp>)
#       320    0.001    0.000    0.001    0.000 widget_float.py:33(_validate_value)
# ...
#         1    0.000    0.000    0.000    0.000 cartan_type.py:2473(__init__)
#         2    0.000    0.000    0.000    0.000 sre_parse.py:296(_class_escape)
#        13    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 category_with_axiom.py:2294(_repr_object_names)
#         3    0.000    0.000    0.000    0.000 traitlets.py:1868(_resolve_string)
#         1    0.000    0.000    0.000    0.000 proof.py:168(get_flag)
#         9    0.000    0.000    0.000    0.000 {built-in method sage.structure.element.canonical_coercion}
#         1    0.000    0.000    0.000    0.000 type_A.py:179(__init__)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:97(closegroup)
#         1    0.000    0.000    0.000    0.000 std.py:47(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.sysconf}
#         3    0.000    0.000    0.000    0.000 iostream.py:304(fileno)
#         1    0.000    0.000    0.000    0.000 category_types.py:49(__init__)
#         1    0.000    0.000    0.000    0.000 weyl_group.py:252(cartan_type)
#         1    0.000    0.000    0.000    0.000 posets.py:2153(<listcomp>)
#         1    0.000    0.000    0.000    0.000 root_system.py:430(is_finite)
#         3    0.000    0.000    0.000    0.000 utils.py:201(_is_utf)
#         2    0.000    0.000    0.000    0.000 sageinspect.py:1851(_sage_getdoc_unformatted)
#         4    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#         3    0.000    0.000    0.000    0.000 utils.py:231(_screen_shape_wrapper)
#         7    0.000    0.000    0.000    0.000 {method 'iterator_verts' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         4    0.000    0.000    0.000    0.000 free_module.py:5974(__hash__)
#        21    0.000    0.000    0.000    0.000 traitlets.py:501(subclass_init)
#         1    0.000    0.000    0.000    0.000 threading.py:1301(_make_invoke_excepthook)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:81(_combine_flags)
#        11    0.000    0.000    0.000    0.000 classical_lie_algebra.py:1588(<genexpr>)
#         1    0.000    0.000    0.000    0.000 category.py:1014(_super_categories_for_classes)
#         1    0.000    0.000    0.000    0.000 free_module.py:3360(submodule)
#         1    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         1    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         1    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 util.py:182(Finalize)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1182(exec_module)
#         1    0.000    0.000    0.000    0.000 category.py:989(_super_categories)
#         1    0.000    0.000    0.001    0.001 root_system.py:534(weight_lattice)
#         6    0.000    0.000    0.000    0.000 ranker.py:107(<genexpr>)
#         2    0.000    0.000    0.000    0.000 dynkin_diagram.py:445(rank)
#         4    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         2    0.000    0.000    0.000    0.000 root_system.py:420(index_set)
#         2    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#        15    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:874(create_module)
#         1    0.000    0.000    0.000    0.000 synchronize.py:210(Condition)
#         1    0.000    0.000    0.000    0.000 {sage.arith.functions.lcm}
#        12    0.000    0.000    0.000    0.000 {built-in method sage.structure.coerce.py_scalar_to_element}
#         1    0.000    0.000    0.000    0.000 std.py:216(EMA)
#         1    0.000    0.000    0.000    0.000 root_system.py:393(dynkin_diagram)
#         5    0.000    0.000    0.000    0.000 {sage.rings.polynomial.multi_polynomial_ring_base.is_MPolynomialRing}
#         1    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 posets.py:1076(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 root_lattice_realizations.py:1215(coroot_space)
#         3    0.000    0.000    0.001    0.000 re.py:249(compile)
#         2    0.000    0.000    0.000    0.000 cartan_matrix.py:292(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(prod)
#         6    0.000    0.000    0.000    0.000 jsonutil.py:52(encode_images)
#        10    0.000    0.000    0.000    0.000 {method 'in_degree' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         4    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         6    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 category.py:2999(super_categories)
#        10    0.000    0.000    0.000    0.000 {method 'iterator_out_nbrs' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         1    0.000    0.000    0.000    0.000 posets.py:1074(<dictcomp>)
#        11    0.000    0.000    0.000    0.000 cartan_type.py:1847(is_affine)
#         1    0.000    0.000    0.000    0.000 matrix_group.py:435(degree)
#         3    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 cartan_type.py:1753(<genexpr>)
#         6    0.000    0.000    0.000    0.000 sre_compile.py:477(_get_iscased)
#         1    0.000    0.000    0.000    0.000 root_system.py:444(is_irreducible)
#         1    0.000    0.000    0.000    0.000 root_system.py:523(coroot_space)
#         1    0.000    0.000    0.000    0.000 digraph.py:3387(<listcomp>)
#         3    0.000    0.000    0.000    0.000 family.py:1042(keys)
#         2    0.000    0.000    0.000    0.000 free_module.py:2052(dimension)
#         6    0.000    0.000    0.000    0.000 backend_ipython.py:64(set_underscore_variable)
#         1    0.000    0.000    0.000    0.000 synchronize.py:186(__init__)
#         5    0.000    0.000    0.000    0.000 digraph.py:900(is_directed)
#         4    0.000    0.000    0.000    0.000 generic_graph.py:3464(get_pos)
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         1    0.000    0.000    0.001    0.001 root_system.py:555(weight_space)
#         6    0.000    0.000    0.000    0.000 indexed_generators.py:183(prefix)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1500(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'rename' of 'sage.structure.sage_object.SageObject' objects}
#         3    0.000    0.000    0.000    0.000 inspect.py:606(getmro)
#         1    0.000    0.000    0.000    0.000 complex_reflection_or_generalized_coxeter_groups.py:115(Irreducible)
#         3    0.000    0.000    0.000    0.000 category.py:2997(<genexpr>)
#        11    0.000    0.000    0.000    0.000 {method 'has_vertex' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:782(_newname)
#         1    0.000    0.000    0.000    0.000 infinity.py:1307(_richcmp_)
#         1    0.000    0.000    0.000    0.000 random.py:119(__init__)
#         1    0.000    0.000    0.000    0.000 generic_graph.py:1198(__copy__)
#         1    0.000    0.000    0.000    0.000 _monitor.py:15(TMonitor)
#         2    0.000    0.000    0.000    0.000 inspect.py:379(iscode)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:646(_validate_hash_pyc)
#         1    0.000    0.000    0.000    0.000 classical_lie_algebra.py:1971(<listcomp>)
#         3    0.000    0.000    0.000    0.000 utils.py:33(<genexpr>)
#         1    0.000    0.000    0.000    0.000 weight_space.py:203(is_extended)
#         1    0.000    0.000    0.000    0.000 context.py:233(get_context)
#         1    0.000    0.000    0.000    0.000 indexed_free_monoid.py:966(one)
#         1    0.000    0.000    0.000    0.000 utils.py:66(Comparable)
#         1    0.000    0.000    0.000    0.000 notebook.py:79(TqdmHBox)
#         1    0.000    0.000    0.000    0.000 generic_graph.py:3037(has_multiple_edges)
#         3    0.000    0.000    0.000    0.000 free_module.py:2497(rank)
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#         2    0.000    0.000    0.000    0.000 utils.py:61(__format__)
#         1    0.000    0.000    0.000    0.000 category.py:1646(parent_class)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1163(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:1198(daemon)
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#         1    0.000    0.000    0.000    0.000 root_lattice_realizations.py:907(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1255(__init__)
#         3    0.000    0.000    0.000    0.000 formatters.py:829(_check_return)
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 classical_lie_algebra.py:1691(<listcomp>)
#         6    0.000    0.000    0.000    0.000 indexed_generators.py:159(<lambda>)
#         1    0.000    0.000    0.000    0.000 util.py:368(ForkAwareThreadLock)
#         1    0.000    0.000    0.000    0.000 free_module.py:5939(<listcomp>)
#         2    0.000    0.000    0.000    0.000 std.py:169(colour)
#         1    0.000    0.000    0.000    0.000 utils.py:112(SimpleTextIOWrapper)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.000    0.000 classical_lie_algebra.py:1973(<listcomp>)
#         1    0.000    0.000    0.000    0.000 comm.py:81(__del__)
#         1    0.000    0.000    0.000    0.000 threading.py:1183(daemon)
#         1    0.000    0.000    0.000    0.000 utils.py:87(ObjectWrapper)
#         1    0.000    0.000    0.000    0.000 synchronize.py:321(Event)
#         1    0.000    0.000    0.000    0.000 category_types.py:87(super_categories)
#         3    0.000    0.000    0.000    0.000 utils.py:34(<genexpr>)
#         1    0.000    0.000    0.000    0.000 category.py:869(<listcomp>)
#         1    0.000    0.000    0.000    0.000 classical_lie_algebra.py:1690(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {method 'denominator' of 'sage.rings.rational.Rational' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#         5    0.000    0.000    0.000    0.000 {method 'num_edges' of 'sage.graphs.base.c_graph.CGraphBackend' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:51(FormatReplace)
#         1    0.000    0.000    0.000    0.000 matrix_group.py:68(is_MatrixGroup)
#         3    0.000    0.000    0.000    0.000 sequence.py:707(universe)
#         1    0.000    0.000    0.000    0.000 std.py:42(TqdmWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:193(_checkLevel)
#         6    0.000    0.000    0.000    0.000 backend_base.py:230(newline)
#         2    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 std.py:100(<listcomp>)
#         1    0.000    0.000    0.000    0.000 weyl_group.py:265(index_set)
#         1    0.000    0.000    0.000    0.000 __init__.py:786(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:175(CallbackIOWrapper)
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#         4    0.000    0.000    0.000    0.000 {method 'num_verts' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         1    0.000    0.000    0.000    0.000 {method 'list' of 'sage.modules.vector_integer_dense.Vector_integer_dense' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:123(Semaphore)
#         1    0.000    0.000    0.000    0.000 {method 'iterator_out_edges' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         1    0.000    0.000    0.000    0.000 util.py:108(_platform_supports_abstract_sockets)
#         2    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         4    0.000    0.000    0.000    0.000 family.py:836(hidden_keys)
#         1    0.000    0.000    0.000    0.000 pushout.py:4077(<listcomp>)
#         2    0.000    0.000    0.000    0.000 rational_field.py:242(_repr_)
#         1    0.000    0.000    0.000    0.000 finite_enumerated_set.py:181(list)
#         1    0.000    0.000    0.000    0.000 family.py:585(__bool__)
#         2    0.000    0.000    0.000    0.000 std.py:1149(__enter__)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 {method 'multiple_edges' of 'sage.graphs.base.static_sparse_backend.StaticSparseBackend' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 morphism.py:356(on_basis)
#         1    0.000    0.000    0.000    0.000 _monitor.py:9(TqdmSynchronisationWarning)
#         1    0.000    0.000    0.000    0.000 synchronize.py:184(RLock)
#         2    0.000    0.000    0.000    0.000 free_module.py:2404(is_sparse)
#         1    0.000    0.000    0.000    0.000 synchronize.py:142(BoundedSemaphore)
#         3    0.000    0.000    0.000    0.000 cartan_type.py:1823(is_irreducible)
#         1    0.000    0.000    0.000    0.000 util.py:385(ForkAwareLocal)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2965(_prod_dispatcher)
#         2    0.000    0.000    0.000    0.000 dynkin_diagram.py:728(odd_isotropic_roots)
#         1    0.000    0.000    0.000    0.000 cartan_matrix.py:519(index_set)
#         1    0.000    0.000    0.000    0.000 process.py:37(current_process)
#         1    0.000    0.000    0.000    0.000 synchronize.py:159(Lock)
#         2    0.000    0.000    0.000    0.000 std.py:165(colour)
#         2    0.000    0.000    0.000    0.000 weight_lattice_realizations.py:167(is_extended)
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#         1    0.000    0.000    0.000    0.000 pushout.py:4078(<listcomp>)
#         1    0.000    0.000    0.000    0.000 auto.py:33(tqdm)
#         1    0.000    0.000    0.000    0.000 context.py:197(get_start_method)
#         1    0.000    0.000    0.000    0.000 type_A.py:46(smallest_base_ring)
#         2    0.000    0.000    0.000    0.000 sets_cat.py:1452(construction)
#         1    0.000    0.000    0.000    0.000 std.py:54(TqdmExperimentalWarning)
#         1    0.000    0.000    0.000    0.000 {sage.rings.integer.is_Integer}
#         1    0.000    0.000    0.000    0.000 cartan_type.py:2610(type)
#         1    0.000    0.000    0.000    0.000 std.py:34(TqdmTypeError)
#         1    0.000    0.000    0.000    0.000 unique_representation.py:1120(__copy__)
#         1    0.000    0.000    0.000    0.000 cartan_type.py:1798(dual)
#         1    0.000    0.000    0.000    0.000 _dist_ver.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 std.py:64(TqdmMonitorWarning)
#         1    0.000    0.000    0.000    0.000 free_module.py:6614(basis)
#         2    0.000    0.000    0.000    0.000 __init__.py:89(<lambda>)
#         1    0.000    0.000    0.000    0.000 pushout.py:4134(<listcomp>)
#         1    0.000    0.000    0.000    0.000 std.py:38(TqdmKeyError)
#         1    0.000    0.000    0.000    0.000 std.py:59(TqdmDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 free_module.py:5115(ambient_module)
#         1    0.000    0.000    0.000    0.000 family.py:422(hidden_keys)
#         1    0.000    0.000    0.000    0.000 pushout.py:4135(<listcomp>)

# %%
import pstats
import io

result = io.StringIO()
stats = pstats.Stats('prun.log',stream=result)
stats.sort_stats("cumulative").print_stats()
result=result.getvalue()
# chop the string into a csv-like buffer
result='ncalls'+result.split('ncalls')[-1]
result='\n'.join([','.join(line.rstrip().split(None,5)) for line in result.split('\n')])
# save it to disk
 
with open('profile.csv', 'w+') as f:
    #f=open(result.rsplit('.')[0]+'.csv','w')
    f.write(result)
    f.close()
