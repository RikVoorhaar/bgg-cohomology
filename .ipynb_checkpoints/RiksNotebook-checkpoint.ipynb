# %%
from bggcomplex import *

BGG = BGGComplex("A3")

reflect = BGG.WeylDic["1"]
BGG.dot_action(reflect,BGG.zero_root)
# Out:
# [-1, 0, 0]

# %%
BGG.plot_graph().plot()
# Out:
# Graphics object consisting of 59 graphics primitives

# %%
from itertools import groupby, chain

vertices=BGG.WeylDic.keys()
arrows=BGG.arrows

outgoing={k:map(lambda x:x[1],v) for k,v in groupby(arrows,lambda x: x[0])}
outgoing[max(vertices,key=lambda x: len(x))]=[]
incoming={k:map(lambda x:x[0],v) for k,v in groupby(arrows,lambda x: x[1])}
incoming['']=[]

# %%
cycles=chain.from_iterable([[a+(v,) for v in outgoing[a[-1]]] for a in arrows])
cycles=chain.from_iterable([[a+(v,) for v in incoming[a[-1]] if v != a[1]] for a in cycles])
cycles=[a+(a[0],) for a in cycles if a[0] in incoming[a[-1]]]

# %% [markdown]
# ## The BGG Graph
#
# We construct the BGG Graph from a given root system. The idea is to do a lot of code just directly in terms of this graph. In particular, we can encode all the BGG maps together with sign directly as a string directly into the edge labels.
#
# Perhaps we should built a new class call BGGGraph with the following methods:
# - signs of the edges
# - maps on the edges
# - maps+signs on the edges
# - admitted cycles
# - get a column of vertices with certain length
# - get all the maps from a given vertex
# - get all the maps between two given columns
# - We can label the vertices with modules, and let it return a basis of these modules
# - We can plot the graph in a pretty way, with optional things like coloring edges by sign, labeling them by map, labeling vertices by the word they represent, by the weight or by the weight module.
# - Directly compute the cohomology of the graph itself
#
# We should then also have a weight-module class with some relevant things

# %% [markdown]
# ## Admissible cycles

# %%
BGGGraph = DiGraph(arrows)
A=BGGGraph.adjacency_matrix(sparse=True)^2

# %%
vertices=BGGGraph.vertices()
cycle_vertices=[[(vertices[i],vertices[j]) for j,b in enumerate(a) if b>1] for i,a in enumerate(A)]
cycle_vertices=list(chain.from_iterable(cycle_vertices))

# %%
cycle_vertices
# Out:
# [('', '12'),
#  ('', '21'),
#  ('1', '121'),
#  ('1', '212'),
#  ('12', '1212'),
#  ('12', '2121'),
#  ('121', '12121'),
#  ('121', '21212'),
#  ('1212', '212121'),
#  ('2', '121'),
#  ('2', '212'),
#  ('21', '1212'),
#  ('21', '2121'),
#  ('212', '12121'),
#  ('212', '21212'),
#  ('2121', '212121')]

# %%
#This code is way too slow. We need to come up with something smarter
#we could just enumerate all the simple paths going forward twice and backward once, 
#then pick those paths for which we can go back
#In principle this should be parellizable on CPU
[BGGGraph.all_simple_paths(starting_vertices=(t[0],),ending_vertices=(t[1],)) for t in cycle_vertices]
# Out:
# [[['', '1', '12'], ['', '2', '12']],
#  [['', '1', '21'], ['', '2', '21']],
#  [['1', '12', '121'], ['1', '21', '121']],
#  [['1', '12', '212'], ['1', '21', '212']],
#  [['12', '121', '1212'], ['12', '212', '1212']],
#  [['12', '121', '2121'], ['12', '212', '2121']],
#  [['121', '1212', '12121'], ['121', '2121', '12121']],
#  [['121', '1212', '21212'], ['121', '2121', '21212']],
#  [['1212', '12121', '212121'], ['1212', '21212', '212121']],
#  [['2', '12', '121'], ['2', '21', '121']],
#  [['2', '12', '212'], ['2', '21', '212']],
#  [['21', '121', '1212'], ['21', '212', '1212']],
#  [['21', '121', '2121'], ['21', '212', '2121']],
#  [['212', '1212', '12121'], ['212', '2121', '12121']],
#  [['212', '1212', '21212'], ['212', '2121', '21212']],
#  [['2121', '12121', '212121'], ['2121', '21212', '212121']]]

# %%
BGG.W.domain()
# Out:
# Ambient space of the Root system of type ['A', 3]

# %%
def get_domain(self):
    return self.W.domain()

# %%
setattr(BGGComplex,'get_domain',get_domain)

# %%
BGG.get_domain()
# Out:
# Ambient space of the Root system of type ['A', 3]

# %%
BGG.graph.arrows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a65682db9779> in <module>()
# ----> 1 BGG.graph.arrows()
#
# AttributeError: 'DiGraph' object has no attribute 'arrows'
